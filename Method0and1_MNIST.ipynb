# %% [markdown]
# # **Method 0: Centralized Training**
#
# This method implements centralized training by utilizing the MNIST dataset in a single node, providing a baseline for comparison against federated learning methods.

# %%
# !pip install -q flwr[simulation] flwr-datasets[vision] torch torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 13.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 59.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 66.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 29.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 20.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 58.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 478.6/478.6 kB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 15.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.16.1 requires protobuf<4.21,>=3.20.3; python_version < "3.11", but you have protobuf 4.25.5 which is incompatible.

# %%
# Import necessary libraries
from collections import OrderedDict
from typing import List, Tuple

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from datasets.utils.logging import disable_progress_bar
from torch.utils.data import DataLoader

import flwr
from flwr.client import Client, ClientApp, NumPyClient
from flwr.common import Metrics, Context
from flwr.server import ServerApp, ServerConfig, ServerAppComponents
from flwr.server.strategy import FedAvg
from flwr.simulation import run_simulation
from flwr_datasets import FederatedDataset

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")
print(f"Flower {flwr.__version__} / PyTorch {torch.__version__}")
disable_progress_bar()
NUM_CLIENTS = 10 # We make 10 clients participate for our FL simualation
BATCH_SIZE = 32

# Data Preprocessing
def load_datasets(partition_id: int):
    fds = FederatedDataset(dataset="mnist", partitioners={"train": NUM_CLIENTS})
    partition = fds.load_partition(partition_id)
    # Divide data on each node: 80% train, 20% test
    partition_train_test = partition.train_test_split(test_size=0.2, seed=42)
    pytorch_transforms = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))]
    )

    def apply_transforms(batch):
        # Apply transformations for MNIST
        batch["image"] = [pytorch_transforms(img) for img in batch["image"]]
        return batch

    # Creating training and validation for each partition and wrap it into DataLoader
    partition_train_test = partition_train_test.with_transform(apply_transforms)
    trainloader = DataLoader(
        partition_train_test["train"], batch_size=BATCH_SIZE, shuffle=True
    )
    valloader = DataLoader(partition_train_test["test"], batch_size=BATCH_SIZE)
    testset = fds.load_split("test").with_transform(apply_transforms)
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloader, valloader, testloader

trainloader, _, _ = load_datasets(partition_id=0)
batch = next(iter(trainloader))
images, labels = batch["image"], batch["label"]

# Reshape and convert images to a NumPy array
images = images.numpy()

# Denormalize the images
images = images * 0.3081 + 0.1307

# Create a figure and a grid of subplots
fig, axs = plt.subplots(4, 8, figsize=(12, 6))

# Plot
for i, ax in enumerate(axs.flat):
    ax.imshow(images[i][0], cmap="gray")
    ax.set_title(trainloader.dataset.features["label"].int2str([labels[i]])[0])
    ax.axis("off")

fig.tight_layout()
plt.show()
# Out:
# Training on cuda
# Flower 1.12.0 / PyTorch 2.5.0+cu121
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/6.97k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/15.6M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/2.60M [00:00<?, ?B/s]

# %%
# CNN Model for MNIST
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 4 * 4, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 4 * 4)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Training function for FL
def train(net, trainloader, epochs: int, verbose=False):
    """Train the network on the training set."""
    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for epoch in range(epochs):
        correct, total, epoch_loss = 0, 0, 0.0
        for batch in trainloader:
            images, labels = batch["image"].to(DEVICE), batch["label"].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            # Metrics
            epoch_loss += loss
            total += labels.size(0)
            correct += (torch.max(outputs.data, 1)[1] == labels).sum().item()
        epoch_loss /= len(trainloader.dataset)
        epoch_acc = correct / total
        if verbose:
            print(f"Epoch {epoch+1}: train loss {epoch_loss}, accuracy {epoch_acc}")
# Testing function for Validation
def test(net, testloader):
    """Evaluate the network on the entire test set."""
    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for batch in testloader:
            images, labels = batch["image"].to(DEVICE), batch["label"].to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %%
trainloader, valloader, testloader = load_datasets(partition_id=0)
net = Net().to(DEVICE)

for epoch in range(20):
    train(net, trainloader, 1)
    loss, accuracy = test(net, valloader)
    print(f"Epoch {epoch+1}: validation loss {loss}, accuracy {accuracy}")

loss, accuracy = test(net, testloader)
print(f"Final test set performance:\n\tloss {loss}\n\taccuracy {accuracy}")
# Out:
# Epoch 1: validation loss 0.011984224965174994, accuracy 0.8575
# Epoch 2: validation loss 0.006061530299484729, accuracy 0.94
# Epoch 3: validation loss 0.004628944432673355, accuracy 0.955
# Epoch 4: validation loss 0.004539645882323385, accuracy 0.9608333333333333
# Epoch 5: validation loss 0.004597065107082017, accuracy 0.96
# Epoch 6: validation loss 0.004369639105473956, accuracy 0.96
# Epoch 7: validation loss 0.002935742567642592, accuracy 0.9733333333333334
# Epoch 8: validation loss 0.0028438717324752363, accuracy 0.9716666666666667
# Epoch 9: validation loss 0.0032881758796672027, accuracy 0.9716666666666667
# Epoch 10: validation loss 0.0030629734788575054, accuracy 0.9725
# Epoch 11: validation loss 0.003078982173586458, accuracy 0.9766666666666667
# Epoch 12: validation loss 0.0024983162933252365, accuracy 0.9775
# Epoch 13: validation loss 0.0025536521042886307, accuracy 0.9816666666666667
# Epoch 14: validation loss 0.005343185826980819, accuracy 0.9583333333333334
# Epoch 15: validation loss 0.003659245929399428, accuracy 0.9708333333333333
# Epoch 16: validation loss 0.005165743711064957, accuracy 0.9608333333333333
# Epoch 17: validation loss 0.0031073554990022484, accuracy 0.9675
# Epoch 18: validation loss 0.0044403572942064784, accuracy 0.97
# Epoch 19: validation loss 0.004592881181318565, accuracy 0.9708333333333333
# Epoch 20: validation loss 0.0037688323188793523, accuracy 0.9758333333333333
# Final test set performance:
# 	loss 0.004948220714544777
# 	accuracy 0.9716

# %% [markdown]
# # **Method 1: Federated Learning with Random Client Selection (FedAvg)**
#
# This method explores the FedAvg algorithm, where a random subset of clients participates in each training round, simulating basic federated learning.

# %%
def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)


def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Define Flower CLient for FL
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config):
        return get_parameters(self.net)

    def fit(self, parameters, config):
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader), {}

    def evaluate(self, parameters, config):
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader), {"accuracy": float(accuracy)}

# %%
# Creating client function
def client_fn(context: Context) -> Client:

    # Load model
    net = Net().to(DEVICE)

    # each client gets a different trainloader/valloader, so each client will train and evaluate on their own unique data partition
    partition_id = context.node_config["partition-id"]
    trainloader, valloader, _ = load_datasets(partition_id=partition_id)

    # Create a single Flower client representing a single organization

    return FlowerClient(net, trainloader, valloader).to_client()


# Creating the ClientApp
client = ClientApp(client_fn=client_fn)

# %%
#FedAvg strategy
strategy = FedAvg(
    fraction_fit=1.0,  # Sample 100% of available clients for training
    fraction_evaluate=0.5,  # Sample 50% of available clients for evaluation
    min_fit_clients=10,  # Never sample less than 10 clients for training
    min_evaluate_clients=5,  # Never sample less than 5 clients for evaluation
    min_available_clients=10,  # Wait until all 10 clients are available
)

# %%
# Creating Server Function
def server_fn(context: Context) -> ServerAppComponents:


    # Configure the server for 5 rounds of training
    config = ServerConfig(num_rounds=5)

    return ServerAppComponents(strategy=strategy, config=config)


# Create the ServerApp
server = ServerApp(server_fn=server_fn)

# %%
backend_config = {"client_resources": {"num_cpus": 1, "num_gpus": 0.0}}

if DEVICE.type == "cuda":
    backend_config = {"client_resources": {"num_cpus": 1, "num_gpus": 1.0}}

# %%
# Run simulation
run_simulation(
    server_app=server,
    client_app=client,
    num_supernodes=NUM_CLIENTS,
    backend_config=backend_config,
)
# Out:
# DEBUG:flwr:Asyncio event loop already running.
# INFO :      Starting Flower ServerApp, config: num_rounds=5, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=2379) 2024-10-29 16:06:46.532338: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2379) 2024-10-29 16:06:46.552488: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2379) 2024-10-29 16:06:46.558647: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2379) 2024-10-29 16:06:48.509941: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2379) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2379) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2379) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2379) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2379) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2379)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 5 round(s) in 234.93s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.013302028315762679
# INFO :      		round 2: 0.0058635989467923835
# INFO :      		round 3: 0.004290554142867525
# INFO :      		round 4: 0.003139902932414164
# INFO :      		round 5: 0.0028461281698352347
# INFO :

# %%
def weighted_average(metrics: List[Tuple[int, Metrics]]) -> Metrics:
    # Multiply accuracy of each client by number of examples used
    accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
    examples = [num_examples for num_examples, _ in metrics]

    # Aggregate and return custom metric (weighted average)
    return {"accuracy": sum(accuracies) / sum(examples)}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def server_fn(context: Context) -> ServerAppComponents:

    # Create FedAvg strategy
    strategy = FedAvg(
        fraction_fit=1.0,
        fraction_evaluate=0.5,
        min_fit_clients=10,
        min_evaluate_clients=5,
        min_available_clients=10,
        evaluate_metrics_aggregation_fn=weighted_average,  # pass the weighted_average function
    )

    # Run it for 20 rpounds
    config = ServerConfig(num_rounds=20)

    return ServerAppComponents(strategy=strategy, config=config)

# Create the ServerApp again
server = ServerApp(server_fn=server_fn)

# Run simulation
run_simulation(
    server_app=server,
    client_app=client,
    num_supernodes=NUM_CLIENTS,
    backend_config=backend_config,
)
# Out:
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=4402) 2024-10-29 16:11:10.872415: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=4402) 2024-10-29 16:11:10.892885: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=4402) 2024-10-29 16:11:10.898828: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=4402) 2024-10-29 16:11:12.041574: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=4402) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=4402) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=4402) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=4402) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=4402) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=4402)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# INFO :      aggregate_fit: received 10 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 933.04s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.011325400233268739
# INFO :      		round 2: 0.005009594818887611
# INFO :      		round 3: 0.0037294169513819118
# INFO :      		round 4: 0.0029950964959959184
# INFO :      		round 5: 0.0026890715839496503
# INFO :      		round 6: 0.0024771400089763727
# INFO :      		round 7: 0.0023072560622628465
# INFO :      		round 8: 0.001984437629425277
# INFO :      		round 9: 0.002001169024500996
# INFO :      		round 10: 0.0018967345574831902
# INFO :      		round 11: 0.0018115307822687706
# INFO :      		round 12: 0.0016292503101091524
# INFO :      		round 13: 0.001591844321437141
# INFO :      		round 14: 0.0013109061761303262
# INFO :      		round 15: 0.0015019076838264785
# INFO :      		round 16: 0.0013878353280306328
# INFO :      		round 17: 0.0013580859360590692
# INFO :      		round 18: 0.0013777684668045064
# INFO :      		round 19: 0.0012392591622822995
# INFO :      		round 20: 0.0013186319108693472
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.9018333333333333),
# INFO :      	              (2, 0.9513333333333334),
# INFO :      	              (3, 0.9623333333333334),
# INFO :      	              (4, 0.9701666666666666),
# INFO :      	              (5, 0.9741666666666665),
# INFO :      	              (6, 0.9753333333333333),
# INFO :      	              (7, 0.9785000000000001),
# INFO :      	              (8, 0.9816666666666666),
# INFO :      	              (9, 0.9780000000000001),
# INFO :      	              (10, 0.9820000000000001),
# INFO :      	              (11, 0.9835),
# INFO :      	              (12, 0.9824999999999999),
# INFO :      	              (13, 0.9851666666666667),
# INFO :      	              (14, 0.9878333333333333),
# INFO :      	              (15, 0.9843333333333334),
# INFO :      	              (16, 0.9858333333333335),
# INFO :      	              (17, 0.9856666666666667),
# INFO :      	              (18, 0.9873333333333333),
# INFO :      	              (19, 0.9876666666666667),
# INFO :      	              (20, 0.9891666666666667)]}
# INFO :

# %% [markdown]
# Centralized Approach: 0.971 Accuracy
#
# FL Approach: 0.9863 Accuracy
#
#
# ---

# %% [markdown]
# **Client Participation (50%, 70%, 20%)**

# %%
# Strategy when 50% clients participate for training
def server_fn_strategy2(context: Context) -> ServerAppComponents:
    strategy2 = FedAvg(
        fraction_fit=0.5,  # 50% of clients participate each round for training
        fraction_evaluate=0.5,  # 50% of clients participate each round for evaluation
        min_fit_clients=5,  # At least 5 clients needed for training
        min_evaluate_clients=5,  # At least 5 clients needed for evaluation
        min_available_clients=10,
        evaluate_metrics_aggregation_fn=weighted_average
    )
    config = ServerConfig(num_rounds=20)
    return ServerAppComponents(strategy=strategy2, config=config)

server_strategy2 = ServerApp(server_fn=server_fn_strategy2)

run_simulation(
    server_app=server_strategy2,
    client_app=client,
    num_supernodes=NUM_CLIENTS,
    backend_config=backend_config,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=11322) 2024-10-29 16:27:09.705977: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=11322) 2024-10-29 16:27:09.726455: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=11322) 2024-10-29 16:27:09.732675: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=11322) 2024-10-29 16:27:10.878400: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=11322) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=11322) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=11322) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=11322) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=11322) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=11322)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 10)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 573.68s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.016299522981047632
# INFO :      		round 2: 0.005051048401743173
# INFO :      		round 3: 0.003979557911244532
# INFO :      		round 4: 0.0028733555285725743
# INFO :      		round 5: 0.0029437765517116837
# INFO :      		round 6: 0.0024622997333838916
# INFO :      		round 7: 0.0022549549299874343
# INFO :      		round 8: 0.0019414221409824674
# INFO :      		round 9: 0.0021124022323444173
# INFO :      		round 10: 0.0020084491558761026
# INFO :      		round 11: 0.0018371258658298752
# INFO :      		round 12: 0.0016502949007068913
# INFO :      		round 13: 0.0016434405716475638
# INFO :      		round 14: 0.0015943898636129842
# INFO :      		round 15: 0.0016818004935000017
# INFO :      		round 16: 0.0017021858751565257
# INFO :      		round 17: 0.0016831359280719575
# INFO :      		round 18: 0.0013608528257439806
# INFO :      		round 19: 0.0014980156080564484
# INFO :      		round 20: 0.001518337593008861
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.8513333333333332),
# INFO :      	              (2, 0.9538333333333333),
# INFO :      	              (3, 0.9611666666666667),
# INFO :      	              (4, 0.9741666666666668),
# INFO :      	              (5, 0.9720000000000001),
# INFO :      	              (6, 0.9765),
# INFO :      	              (7, 0.9786666666666668),
# INFO :      	              (8, 0.9818333333333334),
# INFO :      	              (9, 0.9793333333333334),
# INFO :      	              (10, 0.9803333333333334),
# INFO :      	              (11, 0.9826666666666666),
# INFO :      	              (12, 0.9821666666666667),
# INFO :      	              (13, 0.9816666666666667),
# INFO :      	              (14, 0.9845),
# INFO :      	              (15, 0.9848333333333333),
# INFO :      	              (16, 0.9838333333333333),
# INFO :      	              (17, 0.9835),
# INFO :      	              (18, 0.9865),
# INFO :      	              (19, 0.9856666666666667),
# INFO :      	              (20, 0.9855)]}
# INFO :

# %%
# Strategy when 70% clients participate for training
def server_fn_strategy3(context: Context) -> ServerAppComponents:
    strategy3 = FedAvg(
        fraction_fit=0.7,  # 70% of clients participate each round for training
        fraction_evaluate=0.7,  # 70% of clients participate each round for evaluation
        min_fit_clients=7,  # At least 7 clients needed for training
        min_evaluate_clients=7,  # At least 7 clients needed for evaluation
        min_available_clients=10,
        evaluate_metrics_aggregation_fn=weighted_average
    )
    config = ServerConfig(num_rounds=20)
    return ServerAppComponents(strategy=strategy3, config=config)

server_strategy3 = ServerApp(server_fn=server_fn_strategy3)

run_simulation(
    server_app=server_strategy3,
    client_app=client,
    num_supernodes=NUM_CLIENTS,
    backend_config=backend_config,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=15895) 2024-10-29 16:37:06.456823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=15895) 2024-10-29 16:37:06.477801: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=15895) 2024-10-29 16:37:06.484011: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=15895) 2024-10-29 16:37:07.740326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=15895) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=15895) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=15895) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=15895) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=15895) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=15895)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 7 clients (out of 10)
# INFO :      aggregate_evaluate: received 7 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 804.24s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.0108705400444922
# INFO :      		round 2: 0.005048044009710706
# INFO :      		round 3: 0.0036177172426444786
# INFO :      		round 4: 0.0030781738782700687
# INFO :      		round 5: 0.002510888729288819
# INFO :      		round 6: 0.002394285253221391
# INFO :      		round 7: 0.002093358651687768
# INFO :      		round 8: 0.002001614628825337
# INFO :      		round 9: 0.0018331093401398643
# INFO :      		round 10: 0.0019074933903521878
# INFO :      		round 11: 0.0015756932202375972
# INFO :      		round 12: 0.0016323366462962612
# INFO :      		round 13: 0.0015090738890493028
# INFO :      		round 14: 0.0015430664896710022
# INFO :      		round 15: 0.0013972268457603475
# INFO :      		round 16: 0.001405202196114087
# INFO :      		round 17: 0.0014296984331078767
# INFO :      		round 18: 0.0012782116003602695
# INFO :      		round 19: 0.001518429763103389
# INFO :      		round 20: 0.0013056823791668564
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.9075000000000001),
# INFO :      	              (2, 0.9535714285714286),
# INFO :      	              (3, 0.9660714285714285),
# INFO :      	              (4, 0.968690476190476),
# INFO :      	              (5, 0.9744047619047617),
# INFO :      	              (6, 0.9754761904761906),
# INFO :      	              (7, 0.9792857142857143),
# INFO :      	              (8, 0.9797619047619048),
# INFO :      	              (9, 0.9813095238095237),
# INFO :      	              (10, 0.9817857142857144),
# INFO :      	              (11, 0.9838095238095238),
# INFO :      	              (12, 0.9828571428571429),
# INFO :      	              (13, 0.9840476190476191),
# INFO :      	              (14, 0.9834523809523811),
# INFO :      	              (15, 0.9852380952380955),
# INFO :      	              (16, 0.9863095238095239),
# INFO :      	              (17, 0.9854761904761904),
# INFO :      	              (18, 0.9869047619047618),
# INFO :      	              (19, 0.9858333333333335),
# INFO :      	              (20, 0.9869047619047618)]}
# INFO :

# %%
# Strategy when 20% clients participate for training
def server_fn_strategy4(context: Context) -> ServerAppComponents:
    strategy4 = FedAvg(
        fraction_fit=0.2,  # Only 20% participate in each round for training
        fraction_evaluate=0.2,  # Only 20% participate in each round for evaluation
        min_fit_clients=2,  # At least 2 clients for training
        min_evaluate_clients=2,  # At least 2 clients for evaluation
        min_available_clients=10,
        evaluate_metrics_aggregation_fn=weighted_average
    )
    config = ServerConfig(num_rounds=20)
    return ServerAppComponents(strategy=strategy4, config=config)

server_strategy4 = ServerApp(server_fn=server_fn_strategy4)

run_simulation(
    server_app=server_strategy4,
    client_app=client,
    num_supernodes=NUM_CLIENTS,
    backend_config=backend_config,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# INFO :      Starting Flower ServerApp, config: num_rounds=20, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=22130) 2024-10-29 16:50:56.188448: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=22130) 2024-10-29 16:50:56.219964: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=22130) 2024-10-29 16:50:56.229725: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=22130) 2024-10-29 16:50:58.039983: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=22130) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=22130) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=22130) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=22130) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=22130) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=22130)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_evaluate: received 2 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 234.74s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.012060249627878269
# INFO :      		round 2: 0.005302511863410473
# INFO :      		round 3: 0.004413831449346616
# INFO :      		round 4: 0.003172596581280231
# INFO :      		round 5: 0.0029346451170082825
# INFO :      		round 6: 0.0027037816063966605
# INFO :      		round 7: 0.002685487459821161
# INFO :      		round 8: 0.0018119478563312444
# INFO :      		round 9: 0.0020652850484475494
# INFO :      		round 10: 0.0020612781437618346
# INFO :      		round 11: 0.0020023573755073203
# INFO :      		round 12: 0.001686256782413693
# INFO :      		round 13: 0.002036689230056557
# INFO :      		round 14: 0.0015940592227343586
# INFO :      		round 15: 0.002092044264281867
# INFO :      		round 16: 0.0019911514177510976
# INFO :      		round 17: 0.001959474210652843
# INFO :      		round 18: 0.0018420697990222834
# INFO :      		round 19: 0.001347498779335486
# INFO :      		round 20: 0.0014897855491472
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.88125),
# INFO :      	              (2, 0.9495833333333333),
# INFO :      	              (3, 0.9562499999999999),
# INFO :      	              (4, 0.9691666666666666),
# INFO :      	              (5, 0.97125),
# INFO :      	              (6, 0.9733333333333333),
# INFO :      	              (7, 0.9724999999999999),
# INFO :      	              (8, 0.9808333333333332),
# INFO :      	              (9, 0.9795833333333334),
# INFO :      	              (10, 0.9812500000000001),
# INFO :      	              (11, 0.9787499999999999),
# INFO :      	              (12, 0.9833333333333332),
# INFO :      	              (13, 0.9804166666666667),
# INFO :      	              (14, 0.9841666666666666),
# INFO :      	              (15, 0.9791666666666667),
# INFO :      	              (16, 0.9775),
# INFO :      	              (17, 0.9812499999999998),
# INFO :      	              (18, 0.9804166666666667),
# INFO :      	              (19, 0.9891666666666666),
# INFO :      	              (20, 0.9870833333333333)]}
# INFO :
