# %% [markdown]
# # **Method 3: Dynamic Client Selection with Accuracy Threshold**
#
# This method introduces an accuracy threshold to exclude high-performing clients (accuracy ≥ 0.9) from subsequent rounds, focusing resources on weaker-performing clients.

# %%
# !pip install flwr
# !pip install torch
# !pip install matplotlib
# !pip install torchvision
# !pip install flwr-datasets[vision]
# Out:
# Collecting flwr
#   Downloading flwr-1.13.1-py3-none-any.whl.metadata (15 kB)
# Collecting cryptography<43.0.0,>=42.0.4 (from flwr)
#   Downloading cryptography-42.0.8-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting grpcio!=1.64.2,<2.0.0,<=1.64.3,>=1.60.0 (from flwr)
#   Downloading grpcio-1.64.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting iterators<0.0.3,>=0.0.2 (from flwr)
#   Downloading iterators-0.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from flwr) (1.26.4)
# Collecting pathspec<0.13.0,>=0.12.1 (from flwr)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: protobuf<5.0.0,>=4.25.2 in /usr/local/lib/python3.10/dist-packages (from flwr) (4.25.5)
# Collecting pycryptodome<4.0.0,>=3.18.0 (from flwr)
#   Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: rich<14.0.0,>=13.5.0 in /usr/local/lib/python3.10/dist-packages (from flwr) (13.9.4)
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from flwr) (2.2.1)
# Collecting tomli-w<2.0.0,>=1.0.0 (from flwr)
#   Downloading tomli_w-1.1.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting typer<0.13.0,>=0.12.5 (from flwr)
#   Downloading typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography<43.0.0,>=42.0.4->flwr) (1.17.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=13.5.0->flwr) (4.12.2)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->flwr) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<0.13.0,>=0.12.5->flwr) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography<43.0.0,>=42.0.4->flwr) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.5.0->flwr) (0.1.2)
# Downloading flwr-1.13.1-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 8.3 MB/s eta 0:00:00
# Downloading cryptography-42.0.8-cp39-abi3-manylinux_2_28_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 18.3 MB/s eta 0:00:00
# Downloading grpcio-1.64.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 13.7 MB/s eta 0:00:00
# Downloading iterators-0.0.2-py3-none-any.whl (3.9 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pycryptodome-3.21.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 22.9 MB/s eta 0:00:00
# Downloading tomli_w-1.1.0-py3-none-any.whl (6.4 kB)
# Downloading typer-0.12.5-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: tomli-w, pycryptodome, pathspec, iterators, grpcio, cryptography, typer, flwr
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.68.1
#     Uninstalling grpcio-1.68.1:
#       Successfully uninstalled grpcio-1.68.1
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: typer
#     Found existing installation: typer 0.15.0
#     Uninstalling typer-0.15.0:
#       Successfully uninstalled typer-0.15.0
# Successfully installed cryptography-42.0.8 flwr-1.13.1 grpcio-1.64.3 iterators-0.0.2 pathspec-0.12.1 pycryptodome-3.21.0 tomli-w-1.1.0 typer-0.12.5
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.20.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from torchvision) (2.5.1+cu121)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->torchvision) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->torchvision) (3.0.2)
# Collecting flwr-datasets[vision]
#   Downloading flwr_datasets-0.4.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting datasets<=3.1.0,>=2.14.6 (from flwr-datasets[vision])
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.5 in /usr/local/lib/python3.10/dist-packages (from flwr-datasets[vision]) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from flwr-datasets[vision]) (1.26.4)
# Collecting pyarrow==16.1.0 (from flwr-datasets[vision])
#   Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: seaborn<0.14.0,>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from flwr-datasets[vision]) (0.13.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from flwr-datasets[vision]) (4.66.6)
# Requirement already satisfied: pillow>=6.2.1 in /usr/local/lib/python3.10/dist-packages (from flwr-datasets[vision]) (11.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (3.16.1)
# Collecting dill<0.3.9,>=0.3.0 (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision])
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2.32.3)
# Collecting xxhash (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision])
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision])
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision])
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (3.11.9)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (0.26.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (6.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (4.55.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (2.8.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (4.12.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib<4.0.0,>=3.7.5->flwr-datasets[vision]) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets<=3.1.0,>=2.14.6->flwr-datasets[vision]) (2024.8.30)
# Downloading pyarrow-16.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 20.4 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 24.8 MB/s eta 0:00:00
# Downloading flwr_datasets-0.4.0-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 5.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 11.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.9 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 13.6 MB/s eta 0:00:00
# Installing collected packages: xxhash, pyarrow, fsspec, dill, multiprocess, datasets, flwr-datasets
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 17.0.0
#     Uninstalling pyarrow-17.0.0:
#       Successfully uninstalled pyarrow-17.0.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.1.0 dill-0.3.8 flwr-datasets-0.4.0 fsspec-2024.9.0 multiprocess-0.70.16 pyarrow-16.1.0 xxhash-3.5.0

# %%
# !pip install -q flwr[simulation] flwr-datasets[vision] torch torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 12.5 MB/s eta 0:00:00

# %%
# Import all libraries
from collections import OrderedDict
from typing import List, Tuple, Dict, Optional

import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from datasets.utils.logging import disable_progress_bar
from torch.utils.data import DataLoader

import flwr as fl
from flwr.client import Client, NumPyClient
from flwr.common import Metrics, Parameters, Scalar, FitIns, FitRes, EvaluateRes, Config
from flwr.server import ServerConfig
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import FedAvg
from flwr_datasets import FederatedDataset


random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")


disable_progress_bar()
# Out:
# Training on cpu

# %%
# Global constants
NUM_CLIENTS = 10 # 10 clients participate for FL
NUM_ROUNDS = 20 # Training for 20 rounds
BATCH_SIZE = 32

# %%
# Function to load cifar10 datasets
def load_datasets(partition_id: int):
    fds = FederatedDataset(dataset="cifar10", partitioners={"train": NUM_CLIENTS})
    partition = fds.load_partition(partition_id)
    # Divide data on each node: 80% train, 20% test
    partition_train_test = partition.train_test_split(test_size=0.2, seed=42)
    pytorch_transforms = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )

    def apply_transforms(batch):
        batch["img"] = [pytorch_transforms(img) for img in batch["img"]]
        return batch

    # Create training and validation for each partition
    partition_train_test = partition_train_test.with_transform(apply_transforms)
    trainloader = DataLoader(
        partition_train_test["train"], batch_size=BATCH_SIZE, shuffle=True
    )
    valloader = DataLoader(partition_train_test["test"], batch_size=BATCH_SIZE)
    testset = fds.load_split("test").with_transform(apply_transforms)
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloader, valloader, testloader

# %%
# Model definition for CIFAR10
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# Training function
def train(net, trainloader, epochs: int):

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for _ in range(epochs):
        for batch in trainloader:
            images, labels = batch["img"].to(DEVICE), batch["label"].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

# Testing function
def test(net, testloader):

    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for batch in testloader:
            images, labels = batch["img"].to(DEVICE), batch["label"].to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader.dataset)
    accuracy = correct / total
    return loss, accuracy

# %%
# Functions to set and get model parameters
def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

# %%
# Flower client implementation
class FlowerClient(NumPyClient):
    def __init__(self, net, trainloader, valloader):
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config: Config) -> List[np.ndarray]:
        return get_parameters(self.net)

    def fit(self, parameters: List[np.ndarray], config: Config) -> Tuple[List[np.ndarray], int, Dict]:
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader.dataset), {}

    def evaluate(self, parameters: List[np.ndarray], config: Config) -> Tuple[float, int, Dict]:
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader.dataset), {"accuracy": float(accuracy)}

# %%
# Client function
def client_fn(cid: str) -> Client:

    # Load model
    net = Net().to(DEVICE)
    # Load data
    partition_id = int(cid)
    trainloader, valloader, _ = load_datasets(partition_id)
    # Create and return the Flower client
    return FlowerClient(net, trainloader, valloader)

# %% [markdown]
# Strategy for Accuracy Threshold

# %%
# Dynamic client selection with accuracy threshold, excludes clients above threshold and those with accuracy = 1.0
class CustomFedAvg(FedAvg):
    def __init__(self, accuracy_threshold=0.9, **kwargs):
        super().__init__(**kwargs)
        self.client_accuracies: Dict[str, float] = {}
        self.client_probabilities: Dict[str, float] = {}
        self.metrics_distributed = {"accuracy": []}
        self.latest_parameters: Optional[Parameters] = None
        self.communication_count = 0
        self.terminated = False
        self.accuracy_threshold = accuracy_threshold

    def initialize_clients(self, client_manager: ClientManager):
        for client_proxy in client_manager.all().values():
            cid = client_proxy.cid
            self.client_accuracies[cid] = 0.0
            self.client_probabilities[cid] = 1.0

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, FitIns]]:
        if self.terminated:
            return []

        if server_round == 1:
            self.initialize_clients(client_manager)

        all_clients = list(client_manager.all().values())
        selected_clients = []

        print(f"\nRound {server_round}:")
        for client in all_clients:
            cid = client.cid

            current_accuracy = self.client_accuracies.get(cid, 0.0)

            if current_accuracy >= self.accuracy_threshold:
                self.client_probabilities[cid] = 0.0
                print(f"  Client {cid}: accuracy {current_accuracy:.4f} >= threshold {self.accuracy_threshold}, excluded")
                continue

            # Calculate selection probability p_i(t+1) = 1 - a_i(t)
            probability = 1.0 - current_accuracy
            probability = max(0.0, probability)  # Ensuring that probability is not negative
            self.client_probabilities[cid] = probability

            x = random.uniform(0, 1)
            is_selected = x <= probability
            selection_status = "selected" if is_selected else "not selected"
            print(f"  Client {cid}: p_i({server_round}) = {probability:.4f}, x = {x:.4f}, {selection_status}")
            if is_selected:
                selected_clients.append(client)

        if not selected_clients:
            print("All clients have reached the accuracy threshold. Terminating training.")
            self.terminated = True
            return []

        self.communication_count += len(selected_clients)
        print(f"  Number of clients selected: {len(selected_clients)}")

        config = {}
        fit_ins = FitIns(parameters, config)
        return [(client, fit_ins) for client in selected_clients]

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        aggregated_parameters, aggregated_metrics = super().aggregate_fit(server_round, results, failures)
        if aggregated_parameters is not None:
            self.latest_parameters = aggregated_parameters
        return aggregated_parameters, aggregated_metrics

    def aggregate_evaluate(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, EvaluateRes]],
        failures: List[BaseException],
    ) -> Optional[float]:
        metrics = []
        participating_cids = [client_proxy.cid for client_proxy, _ in results]

        for client_proxy, evaluate_res in results:
            cid = client_proxy.cid
            num_examples = evaluate_res.num_examples
            accuracy = evaluate_res.metrics.get("accuracy", 0.0)
            self.client_accuracies[cid] = accuracy
            metrics.append((num_examples, {"accuracy": accuracy}))

        print(f"\nRound {server_round} client accuracies:")
        for cid in self.client_accuracies.keys():
            accuracy = self.client_accuracies[cid]
            status = "participated" if cid in participating_cids else "did not participate"
            print(f"  Client {cid}: accuracy = {accuracy:.4f} ({status})")

        aggregated_metrics = self.weighted_average(metrics)
        global_accuracy = aggregated_metrics["accuracy"]
        self.metrics_distributed["accuracy"].append((server_round, global_accuracy))
        print(f"Round {server_round} aggregated accuracy: {global_accuracy:.4f}")
        return super().aggregate_evaluate(server_round, results, failures)

    @staticmethod
    def weighted_average(metrics: List[Tuple[int, Dict[str, Scalar]]]) -> Dict[str, Scalar]:
        accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
        examples = [num_examples for num_examples, _ in metrics]
        if sum(examples) == 0:
            return {"accuracy": 0.0}
        return {"accuracy": sum(accuracies) / sum(examples)}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
NUM_CLIENTS = 10
NUM_ROUNDS = 20
ACCURACY_THRESHOLD = 0.9  # Adjust the threshold as needed

strategy1 = CustomFedAvg(
    accuracy_threshold=ACCURACY_THRESHOLD,
    fraction_fit=1.0,         # All clients are considered in selection
    min_fit_clients=1,        # At least one client should be available
    min_available_clients=NUM_CLIENTS,
)

# %%
server_config1 = ServerConfig(num_rounds=NUM_ROUNDS)

# %%
# Start the simulation
history = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    client_resources={"num_gpus": 0.5 if torch.cuda.is_available() else 0},
    config=server_config1,
    strategy=strategy1,
)
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# 2024-11-20 16:37:58,991	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'object_store_memory': 3985311744.0, 'GPU': 1.0, 'node:172.28.0.12': 1.0, 'node:__internal_head__': 1.0, 'CPU': 2.0, 'accelerator_type:T4': 1.0, 'memory': 7970623488.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# <ipython-input-18-07c849282ceb>:2: UserWarning: No `num_cpus` specified in `client_resources`. Using `num_cpus=1` for each client.
#   history = fl.simulation.start_simulation(
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_gpus': 0.5, 'num_cpus': 1}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=2088) 2024-11-20 16:38:02.528072: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2088) 2024-11-20 16:38:02.561764: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2088) 2024-11-20 16:38:02.577730: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2088) 2024-11-20 16:38:04.373668: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2088) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2088) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2088) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2088) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2088) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2088)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (pid=2087) 2024-11-20 16:38:02.526007: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2087) 2024-11-20 16:38:02.559622: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2087) 2024-11-20 16:38:02.572036: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2087) 2024-11-20 16:38:04.359099: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2088)
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating train split:  22%|██▏       | 11100/50000 [00:00<00:00, 109076.20 examples/s]
# Generating train split:  45%|████▌     | 22500/50000 [00:00<00:00, 111798.56 examples/s]
# Generating train split:  76%|███████▌  | 38000/50000 [00:00<00:00, 106510.04 examples/s]
# Generating train split: 100%|██████████| 50000/50000 [00:00<00:00, 108490.79 examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 110028.96 examples/s]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2088)
# Round 1:
#   Client 12181256285627983242: p_i(1) = 1.0000, x = 0.1248, selected
#   Client 1210614331923740713: p_i(1) = 1.0000, x = 0.9223, selected
#   Client 15944661990935152649: p_i(1) = 1.0000, x = 0.0788, selected
#   Client 6118765773027473396: p_i(1) = 1.0000, x = 0.2932, selected
#   Client 17989910189733210341: p_i(1) = 1.0000, x = 0.6286, selected
#   Client 10713676711731053921: p_i(1) = 1.0000, x = 0.8855, selected
#   Client 3145822975221503828: p_i(1) = 1.0000, x = 0.3616, selected
#   Client 10079589147956201026: p_i(1) = 1.0000, x = 0.1923, selected
#   Client 16794294093924577341: p_i(1) = 1.0000, x = 0.0696, selected
#   Client 8219245920631037001: p_i(1) = 1.0000, x = 0.6613, selected
#   Number of clients selected: 10
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2087) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2087) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2087) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2087) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2087) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2087)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2087)
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2087)             entirely in future versions of Flower.
# (ClientAppActor pid=2087)
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=2088)          [repeated 4x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2088)          [repeated 4x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)          [repeated 8x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 9 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# Round 1 client accuracies:
#   Client 12181256285627983242: accuracy = 0.2610 (participated)
#   Client 1210614331923740713: accuracy = 0.2540 (participated)
#   Client 15944661990935152649: accuracy = 0.2670 (participated)
#   Client 6118765773027473396: accuracy = 0.2500 (participated)
#   Client 17989910189733210341: accuracy = 0.2590 (participated)
#   Client 10713676711731053921: accuracy = 0.2420 (participated)
#   Client 3145822975221503828: accuracy = 0.2400 (participated)
#   Client 10079589147956201026: accuracy = 0.2660 (participated)
#   Client 16794294093924577341: accuracy = 0.2430 (participated)
#   Client 8219245920631037001: accuracy = 0.2590 (participated)
# Round 1 aggregated accuracy: 0.2541
#
# Round 2:
#   Client 12181256285627983242: p_i(2) = 0.7390, x = 0.3702, selected
#   Client 1210614331923740713: p_i(2) = 0.7460, x = 0.2095, selected
#   Client 15944661990935152649: p_i(2) = 0.7330, x = 0.2670, selected
#   Client 6118765773027473396: p_i(2) = 0.7500, x = 0.9367, not selected
#   Client 17989910189733210341: p_i(2) = 0.7410, x = 0.6480, selected
#   Client 10713676711731053921: p_i(2) = 0.7580, x = 0.6091, selected
#   Client 3145822975221503828: p_i(2) = 0.7600, x = 0.1711, selected
#   Client 10079589147956201026: p_i(2) = 0.7340, x = 0.7291, selected
#   Client 16794294093924577341: p_i(2) = 0.7570, x = 0.1634, selected
#   Client 8219245920631037001: p_i(2) = 0.7410, x = 0.3795, selected
#   Number of clients selected: 9
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 9 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# Round 2 client accuracies:
#   Client 12181256285627983242: accuracy = 0.3730 (participated)
#   Client 1210614331923740713: accuracy = 0.3380 (participated)
#   Client 15944661990935152649: accuracy = 0.3670 (participated)
#   Client 6118765773027473396: accuracy = 0.3310 (participated)
#   Client 17989910189733210341: accuracy = 0.3530 (participated)
#   Client 10713676711731053921: accuracy = 0.3290 (participated)
#   Client 3145822975221503828: accuracy = 0.3350 (participated)
#   Client 10079589147956201026: accuracy = 0.3490 (participated)
#   Client 16794294093924577341: accuracy = 0.3200 (participated)
#   Client 8219245920631037001: accuracy = 0.3420 (participated)
# Round 2 aggregated accuracy: 0.3437
#
# Round 3:
#   Client 12181256285627983242: p_i(3) = 0.6270, x = 0.0662, selected
#   Client 1210614331923740713: p_i(3) = 0.6620, x = 0.9131, not selected
#   Client 15944661990935152649: p_i(3) = 0.6330, x = 0.5672, selected
#   Client 6118765773027473396: p_i(3) = 0.6690, x = 0.7179, not selected
#   Client 17989910189733210341: p_i(3) = 0.6470, x = 0.2126, selected
#   Client 10713676711731053921: p_i(3) = 0.6710, x = 0.4992, selected
#   Client 3145822975221503828: p_i(3) = 0.6650, x = 0.8847, not selected
#   Client 10079589147956201026: p_i(3) = 0.6510, x = 0.6429, selected
#   Client 16794294093924577341: p_i(3) = 0.6800, x = 0.1429, selected
#   Client 8219245920631037001: p_i(3) = 0.6580, x = 0.1396, selected
#   Number of clients selected: 7
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)          [repeated 10x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=2088)          [repeated 12x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# Round 3 client accuracies:
#   Client 12181256285627983242: accuracy = 0.4250 (participated)
#   Client 1210614331923740713: accuracy = 0.3820 (participated)
#   Client 15944661990935152649: accuracy = 0.4070 (participated)
#   Client 6118765773027473396: accuracy = 0.3950 (participated)
#   Client 17989910189733210341: accuracy = 0.3950 (participated)
#   Client 10713676711731053921: accuracy = 0.3750 (participated)
#   Client 3145822975221503828: accuracy = 0.4040 (participated)
#   Client 10079589147956201026: accuracy = 0.4080 (participated)
#   Client 16794294093924577341: accuracy = 0.3830 (participated)
#   Client 8219245920631037001: accuracy = 0.3620 (participated)
# Round 3 aggregated accuracy: 0.3936
#
# Round 4:
#   Client 12181256285627983242: p_i(4) = 0.5750, x = 0.5095, selected
#   Client 1210614331923740713: p_i(4) = 0.6180, x = 0.0909, selected
#   Client 15944661990935152649: p_i(4) = 0.5930, x = 0.0471, selected
#   Client 6118765773027473396: p_i(4) = 0.6050, x = 0.1096, selected
#   Client 17989910189733210341: p_i(4) = 0.6050, x = 0.6274, not selected
#   Client 10713676711731053921: p_i(4) = 0.6250, x = 0.7921, not selected
#   Client 3145822975221503828: p_i(4) = 0.5960, x = 0.4222, selected
#   Client 10079589147956201026: p_i(4) = 0.5920, x = 0.0635, selected
#   Client 16794294093924577341: p_i(4) = 0.6170, x = 0.3816, selected
#   Client 8219245920631037001: p_i(4) = 0.6380, x = 0.9961, not selected
#   Number of clients selected: 7
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)          [repeated 2x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2087)          [repeated 8x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# Round 4 client accuracies:
#   Client 12181256285627983242: accuracy = 0.4370 (participated)
#   Client 1210614331923740713: accuracy = 0.4030 (participated)
#   Client 15944661990935152649: accuracy = 0.4300 (participated)
#   Client 6118765773027473396: accuracy = 0.4050 (participated)
#   Client 17989910189733210341: accuracy = 0.4160 (participated)
#   Client 10713676711731053921: accuracy = 0.4010 (participated)
#   Client 3145822975221503828: accuracy = 0.4230 (participated)
#   Client 10079589147956201026: accuracy = 0.4560 (participated)
#   Client 16794294093924577341: accuracy = 0.4070 (participated)
#   Client 8219245920631037001: accuracy = 0.3970 (participated)
# Round 4 aggregated accuracy: 0.4175
#
# Round 5:
#   Client 12181256285627983242: p_i(5) = 0.5630, x = 0.2935, selected
#   Client 1210614331923740713: p_i(5) = 0.5970, x = 0.1582, selected
#   Client 15944661990935152649: p_i(5) = 0.5700, x = 0.0032, selected
#   Client 6118765773027473396: p_i(5) = 0.5950, x = 0.7221, not selected
#   Client 17989910189733210341: p_i(5) = 0.5840, x = 0.7197, not selected
#   Client 10713676711731053921: p_i(5) = 0.5990, x = 0.9719, not selected
#   Client 3145822975221503828: p_i(5) = 0.5770, x = 0.7620, not selected
#   Client 10079589147956201026: p_i(5) = 0.5440, x = 0.5077, selected
#   Client 16794294093924577341: p_i(5) = 0.5930, x = 0.1064, selected
#   Client 8219245920631037001: p_i(5) = 0.6030, x = 0.6253, not selected
#   Number of clients selected: 5
# (ClientAppActor pid=2088)          [repeated 8x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2087)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 10)
# Round 5 client accuracies:
#   Client 12181256285627983242: accuracy = 0.4540 (participated)
#   Client 1210614331923740713: accuracy = 0.4370 (participated)
#   Client 15944661990935152649: accuracy = 0.4470 (participated)
#   Client 6118765773027473396: accuracy = 0.4250 (participated)
#   Client 17989910189733210341: accuracy = 0.4300 (participated)
#   Client 10713676711731053921: accuracy = 0.4230 (participated)
#   Client 3145822975221503828: accuracy = 0.4590 (participated)
#   Client 10079589147956201026: accuracy = 0.4610 (participated)
#   Client 16794294093924577341: accuracy = 0.4380 (participated)
#   Client 8219245920631037001: accuracy = 0.4130 (participated)
# Round 5 aggregated accuracy: 0.4387
#
# Round 6:
#   Client 12181256285627983242: p_i(6) = 0.5460, x = 0.0195, selected
#   Client 1210614331923740713: p_i(6) = 0.5630, x = 0.9291, not selected
#   Client 15944661990935152649: p_i(6) = 0.5530, x = 0.8787, not selected
#   Client 6118765773027473396: p_i(6) = 0.5750, x = 0.8317, not selected
#   Client 17989910189733210341: p_i(6) = 0.5700, x = 0.3075, selected
#   Client 10713676711731053921: p_i(6) = 0.5770, x = 0.0579, selected
#   Client 3145822975221503828: p_i(6) = 0.5410, x = 0.8780, not selected
#   Client 10079589147956201026: p_i(6) = 0.5390, x = 0.9469, not selected
#   Client 16794294093924577341: p_i(6) = 0.5620, x = 0.0857, selected
#   Client 8219245920631037001: p_i(6) = 0.5870, x = 0.4860, selected
#   Number of clients selected: 5
# (ClientAppActor pid=2087)          [repeated 8x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2088)             entirely in future versions of Flower.
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 4 clients (out of 10)
# (ClientAppActor pid=2088)          [repeated 8x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# Round 6 client accuracies:
#   Client 12181256285627983242: accuracy = 0.4670 (participated)
#   Client 1210614331923740713: accuracy = 0.4490 (participated)
#   Client 15944661990935152649: accuracy = 0.4750 (participated)
#   Client 6118765773027473396: accuracy = 0.4410 (participated)
#   Client 17989910189733210341: accuracy = 0.4510 (participated)
#   Client 10713676711731053921: accuracy = 0.4400 (participated)
#   Client 3145822975221503828: accuracy = 0.4610 (participated)
#   Client 10079589147956201026: accuracy = 0.4680 (participated)
#   Client 16794294093924577341: accuracy = 0.4410 (participated)
#   Client 8219245920631037001: accuracy = 0.4460 (participated)
# Round 6 aggregated accuracy: 0.4539
#
# Round 7:
#   Client 12181256285627983242: p_i(7) = 0.5330, x = 0.9289, not selected
#   Client 1210614331923740713: p_i(7) = 0.5510, x = 0.7553, not selected
#   Client 15944661990935152649: p_i(7) = 0.5250, x = 0.6899, not selected
#   Client 6118765773027473396: p_i(7) = 0.5590, x = 0.7129, not selected
#   Client 17989910189733210341: p_i(7) = 0.5490, x = 0.3990, selected
#   Client 10713676711731053921: p_i(7) = 0.5600, x = 0.6717, not selected
#   Client 3145822975221503828: p_i(7) = 0.5390, x = 0.3734, selected
#   Client 10079589147956201026: p_i(7) = 0.5320, x = 0.8996, not selected
#   Client 16794294093924577341: p_i(7) = 0.5590, x = 0.4515, selected
#   Client 8219245920631037001: p_i(7) = 0.5540, x = 0.2479, selected
#   Number of clients selected: 4
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# INFO :      aggregate_fit: received 4 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2088)          [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# ...
#   Client 3145822975221503828: accuracy = 0.5450 (participated)
#   Client 10079589147956201026: accuracy = 0.5650 (participated)
#   Client 16794294093924577341: accuracy = 0.5430 (participated)
#   Client 8219245920631037001: accuracy = 0.5310 (participated)
# Round 17 aggregated accuracy: 0.5451
#
# Round 18:
#   Client 12181256285627983242: p_i(18) = 0.4400, x = 0.1996, selected
#   Client 1210614331923740713: p_i(18) = 0.4840, x = 0.9185, not selected
#   Client 15944661990935152649: p_i(18) = 0.4310, x = 0.3497, selected
#   Client 6118765773027473396: p_i(18) = 0.4690, x = 0.8205, not selected
#   Client 17989910189733210341: p_i(18) = 0.4510, x = 0.8713, not selected
#   Client 10713676711731053921: p_i(18) = 0.4580, x = 0.2229, selected
#   Client 3145822975221503828: p_i(18) = 0.4550, x = 0.6600, not selected
#   Client 10079589147956201026: p_i(18) = 0.4350, x = 0.3985, selected
#   Client 16794294093924577341: p_i(18) = 0.4570, x = 0.2786, selected
#   Client 8219245920631037001: p_i(18) = 0.4690, x = 0.0694, selected
#   Number of clients selected: 6
# (ClientAppActor pid=2087)          [repeated 10x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# INFO :      aggregate_fit: received 6 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2088)          [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 4 clients (out of 10)
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# Round 18 client accuracies:
#   Client 12181256285627983242: accuracy = 0.5550 (participated)
#   Client 1210614331923740713: accuracy = 0.5250 (participated)
#   Client 15944661990935152649: accuracy = 0.5750 (participated)
#   Client 6118765773027473396: accuracy = 0.5290 (participated)
#   Client 17989910189733210341: accuracy = 0.5460 (participated)
#   Client 10713676711731053921: accuracy = 0.5510 (participated)
#   Client 3145822975221503828: accuracy = 0.5630 (participated)
#   Client 10079589147956201026: accuracy = 0.5800 (participated)
#   Client 16794294093924577341: accuracy = 0.5500 (participated)
#   Client 8219245920631037001: accuracy = 0.5180 (participated)
# Round 18 aggregated accuracy: 0.5492
#
# Round 19:
#   Client 12181256285627983242: p_i(19) = 0.4450, x = 0.5806, not selected
#   Client 1210614331923740713: p_i(19) = 0.4750, x = 0.9836, not selected
#   Client 15944661990935152649: p_i(19) = 0.4250, x = 0.0383, selected
#   Client 6118765773027473396: p_i(19) = 0.4710, x = 0.5966, not selected
#   Client 17989910189733210341: p_i(19) = 0.4540, x = 0.3457, selected
#   Client 10713676711731053921: p_i(19) = 0.4490, x = 0.7864, not selected
#   Client 3145822975221503828: p_i(19) = 0.4370, x = 0.4364, selected
#   Client 10079589147956201026: p_i(19) = 0.4200, x = 0.9842, not selected
#   Client 16794294093924577341: p_i(19) = 0.4500, x = 0.1156, selected
#   Client 8219245920631037001: p_i(19) = 0.4820, x = 0.8995, not selected
#   Number of clients selected: 4
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2087) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# INFO :      aggregate_fit: received 4 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2087)          [repeated 6x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2087)          [repeated 8x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# Round 19 client accuracies:
#   Client 12181256285627983242: accuracy = 0.5710 (participated)
#   Client 1210614331923740713: accuracy = 0.5380 (participated)
#   Client 15944661990935152649: accuracy = 0.5750 (participated)
#   Client 6118765773027473396: accuracy = 0.5270 (participated)
#   Client 17989910189733210341: accuracy = 0.5590 (participated)
#   Client 10713676711731053921: accuracy = 0.5490 (participated)
#   Client 3145822975221503828: accuracy = 0.5480 (participated)
#   Client 10079589147956201026: accuracy = 0.5780 (participated)
#   Client 16794294093924577341: accuracy = 0.5560 (participated)
#   Client 8219245920631037001: accuracy = 0.5330 (participated)
# Round 19 aggregated accuracy: 0.5534
#
# Round 20:
#   Client 12181256285627983242: p_i(20) = 0.4290, x = 0.9489, not selected
#   Client 1210614331923740713: p_i(20) = 0.4620, x = 0.9208, not selected
#   Client 15944661990935152649: p_i(20) = 0.4250, x = 0.6232, not selected
#   Client 6118765773027473396: p_i(20) = 0.4730, x = 0.6634, not selected
#   Client 17989910189733210341: p_i(20) = 0.4410, x = 0.1246, selected
#   Client 10713676711731053921: p_i(20) = 0.4510, x = 0.9000, not selected
#   Client 3145822975221503828: p_i(20) = 0.4520, x = 0.5071, not selected
#   Client 10079589147956201026: p_i(20) = 0.4220, x = 0.6669, not selected
#   Client 16794294093924577341: p_i(20) = 0.4440, x = 0.3262, selected
#   Client 8219245920631037001: p_i(20) = 0.4670, x = 0.6972, not selected
#   Number of clients selected: 2
# (ClientAppActor pid=2087)          [repeated 10x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2087)          [repeated 4x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2087) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2087)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2087)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2088)          [repeated 10x across cluster]
# (ClientAppActor pid=2088) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2088) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2088)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2088)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 507.77s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06544832537174225
# INFO :      		round 2: 0.057042555451393126
# INFO :      		round 3: 0.053028796660900115
# INFO :      		round 4: 0.05069191427230835
# INFO :      		round 5: 0.04934219335317612
# INFO :      		round 6: 0.04834772934317589
# INFO :      		round 7: 0.04722871626615524
# INFO :      		round 8: 0.04612251586914062
# INFO :      		round 9: 0.045279910600185394
# INFO :      		round 10: 0.044828261893987656
# INFO :      		round 11: 0.04390035212039947
# INFO :      		round 12: 0.04349105659723282
# INFO :      		round 13: 0.042766574728488924
# INFO :      		round 14: 0.042669638097286224
# INFO :      		round 15: 0.04177885027527809
# INFO :      		round 16: 0.04113664180040359
# INFO :      		round 17: 0.040785205727815625
# INFO :      		round 18: 0.04058518087863922
# INFO :      		round 19: 0.04011328605413437
# INFO :      		round 20: 0.04036890587210655
# INFO :
# Round 20 client accuracies:
#   Client 12181256285627983242: accuracy = 0.5630 (participated)
#   Client 1210614331923740713: accuracy = 0.5320 (participated)
#   Client 15944661990935152649: accuracy = 0.5660 (participated)
#   Client 6118765773027473396: accuracy = 0.5350 (participated)
#   Client 17989910189733210341: accuracy = 0.5430 (participated)
#   Client 10713676711731053921: accuracy = 0.5370 (participated)
#   Client 3145822975221503828: accuracy = 0.5460 (participated)
#   Client 10079589147956201026: accuracy = 0.5660 (participated)
#   Client 16794294093924577341: accuracy = 0.5580 (participated)
#   Client 8219245920631037001: accuracy = 0.5280 (participated)
# Round 20 aggregated accuracy: 0.5474

# %%
# Communication rounds
print(f"\nTotal communication counts (number of client participations): {strategy1.communication_count}")
# Out:
# Total communication counts (number of client participations): 109

# %% [markdown]
# # **Method 4: Client Selection Based on Performance Comparison**
#
# This method selects clients whose accuracy has not improved over previous rounds, prioritizing underperforming clients to enhance global model convergence.

# %%
from typing import Dict, List, Optional, Tuple

import flwr as fl
from flwr.common import (
    Parameters,
    Scalar,
    FitIns,
    FitRes,
    EvaluateRes,
)
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy

class Aquib(fl.server.strategy.FedAvg):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.client_accuracies: Dict[str, float] = {}
        self.previous_client_accuracies: Dict[str, Optional[float]] = {}
        self.communication_count = 0
        self.terminated = False

    def initialize_clients(self, client_manager: ClientManager):
        for client_proxy in client_manager.all().values():
            cid = client_proxy.cid
            # Initialize previous accuracies to None
            self.previous_client_accuracies[cid] = None
            self.client_accuracies[cid] = 0.0

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, FitIns]]:
        if self.terminated:
            return []

        if server_round == 1:
            self.initialize_clients(client_manager)

        all_clients = list(client_manager.all().values())
        selected_clients = []

        print(f"\nRound {server_round}:")
        for client in all_clients:
            cid = client.cid

            current_accuracy = self.client_accuracies.get(cid, 0.0)
            previous_accuracy = self.previous_client_accuracies.get(cid)

            # Determine if the client is underperforming
            if previous_accuracy is None:
                # First round, consider all clients as underperforming
                underperforming = True
            else:
                if current_accuracy <= previous_accuracy:
                    underperforming = True
                else:
                    underperforming = False

            if underperforming:
                # Client is underperforming, select for training
                print(f"  Client {cid}: Underperforming (prev: {previous_accuracy}, current: {current_accuracy}), selected")
                selected_clients.append(client)
            else:
                # Client is performing well, do not select for training
                print(f"  Client {cid}: Performing well (prev: {previous_accuracy}, current: {current_accuracy}), not selected")

        if not selected_clients:
            print("All clients are performing well. Terminating training.")
            self.terminated = True
            return []

        self.communication_count += len(selected_clients)
        print(f"  Number of clients selected: {len(selected_clients)}")

        # Prepare fit instructions
        config = {}
        fit_ins = FitIns(parameters, config)
        return [(client, fit_ins) for client in selected_clients]

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        # Call super to aggregate parameters as usual
        aggregated_parameters, aggregated_metrics = super().aggregate_fit(server_round, results, failures)
        if aggregated_parameters is not None:
            self.latest_parameters = aggregated_parameters
        return aggregated_parameters, aggregated_metrics

    def aggregate_evaluate(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, EvaluateRes]],
        failures: List[BaseException],
    ) -> Optional[float]:
        metrics = []
        participating_cids = [client_proxy.cid for client_proxy, _ in results]

        for client_proxy, evaluate_res in results:
            cid = client_proxy.cid
            num_examples = evaluate_res.num_examples
            accuracy = evaluate_res.metrics.get("accuracy", 0.0)

            # Update previous accuracy
            self.previous_client_accuracies[cid] = self.client_accuracies.get(cid, 0.0)
            # Update current accuracy
            self.client_accuracies[cid] = accuracy

            metrics.append((num_examples, {"accuracy": accuracy}))

        print(f"\nRound {server_round} client accuracies:")
        for cid in self.client_accuracies.keys():
            current_accuracy = self.client_accuracies[cid]
            previous_accuracy = self.previous_client_accuracies[cid]
            status = "participated" if cid in participating_cids else "did not participate"
            print(f"  Client {cid}: accuracy = {current_accuracy:.4f} (prev: {previous_accuracy}, {status})")

        aggregated_metrics = self.weighted_average(metrics)
        global_accuracy = aggregated_metrics["accuracy"]
        print(f"Round {server_round} aggregated accuracy: {global_accuracy:.4f}")

        return super().aggregate_evaluate(server_round, results, failures)

    @staticmethod
    def weighted_average(metrics: List[Tuple[int, Dict[str, Scalar]]]) -> Dict[str, Scalar]:
        accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
        examples = [num_examples for num_examples, _ in metrics]
        if sum(examples) == 0:
            return {"accuracy": 0.0}
        return {"accuracy": sum(accuracies) / sum(examples)}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
NUM_CLIENTS = 10
NUM_ROUNDS = 20

strategy4 = Aquib(
    fraction_fit=1.0,         # All clients are considered in selection
    min_fit_clients=1,        # At least one client should be available
    min_available_clients=NUM_CLIENTS,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
server_config4 = ServerConfig(num_rounds=NUM_ROUNDS)

# Start the simulation
history = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    client_resources={"num_gpus": 0.5 if torch.cuda.is_available() else 0},
    config=server_config4,
    strategy=strategy4,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# 2024-11-22 09:48:46,850	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 2.0, 'memory': 7988222363.0, 'object_store_memory': 3994111180.0, 'node:172.28.0.12': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# <ipython-input-16-93801a22dc50>:4: UserWarning: No `num_cpus` specified in `client_resources`. Using `num_cpus=1` for each client.
#   history = fl.simulation.start_simulation(
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_gpus': 0, 'num_cpus': 1}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=9221) 2024-11-22 09:48:51.301023: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=9221) 2024-11-22 09:48:51.362000: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=9221) 2024-11-22 09:48:51.377018: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=9221) 2024-11-22 09:48:53.614136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=9221) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=9221) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=9221) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=9221) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=9221) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=9221)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9221)
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9221)             entirely in future versions of Flower.
# (ClientAppActor pid=9221)
# (pid=9219) 2024-11-22 09:48:51.397647: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=9219) 2024-11-22 09:48:51.438657: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=9219) 2024-11-22 09:48:51.450434: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=9219) 2024-11-22 09:48:53.651828: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9221)
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9221)             entirely in future versions of Flower.
# (ClientAppActor pid=9221)
# Round 1:
#   Client 10892504397625728372: Underperforming (prev: None, current: 0.0), selected
#   Client 15042521525871969850: Underperforming (prev: None, current: 0.0), selected
#   Client 4575084854179807627: Underperforming (prev: None, current: 0.0), selected
#   Client 13624414457441813354: Underperforming (prev: None, current: 0.0), selected
#   Client 10344505357825835331: Underperforming (prev: None, current: 0.0), selected
#   Client 15054063207148904620: Underperforming (prev: None, current: 0.0), selected
#   Client 6052036123941770588: Underperforming (prev: None, current: 0.0), selected
#   Client 16306295208814201252: Underperforming (prev: None, current: 0.0), selected
#   Client 4372068911019174871: Underperforming (prev: None, current: 0.0), selected
#   Client 6010294342599894056: Underperforming (prev: None, current: 0.0), selected
#   Number of clients selected: 10
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9221)
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9221)             entirely in future versions of Flower.
# (ClientAppActor pid=9221)
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=9219) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=9219) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=9219) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=9219) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=9219) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=9219)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9219)
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9219)             entirely in future versions of Flower.
# (ClientAppActor pid=9219)
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=9219)          [repeated 4x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=9219)          [repeated 4x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=9221)          [repeated 6x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 3x across cluster]
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9219)          [repeated 2x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9219)             entirely in future versions of Flower.
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9221)             entirely in future versions of Flower.
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 7x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 1 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.0, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.0, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.0, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.0, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.0, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.0, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.0, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.0, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.0, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.0, participated)
# Round 1 aggregated accuracy: 0.2973
#
# Round 2:
#   Client 10892504397625728372: Performing well (prev: 0.0, current: 0.312), not selected
#   Client 15042521525871969850: Performing well (prev: 0.0, current: 0.28), not selected
#   Client 4575084854179807627: Performing well (prev: 0.0, current: 0.316), not selected
#   Client 13624414457441813354: Performing well (prev: 0.0, current: 0.287), not selected
#   Client 10344505357825835331: Performing well (prev: 0.0, current: 0.292), not selected
#   Client 15054063207148904620: Performing well (prev: 0.0, current: 0.274), not selected
#   Client 6052036123941770588: Performing well (prev: 0.0, current: 0.32), not selected
#   Client 16306295208814201252: Performing well (prev: 0.0, current: 0.304), not selected
#   Client 4372068911019174871: Performing well (prev: 0.0, current: 0.29), not selected
#   Client 6010294342599894056: Performing well (prev: 0.0, current: 0.298), not selected
# All clients are performing well. Terminating training.
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 10x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 2 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 2 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# (ClientAppActor pid=9221)          [repeated 16x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 8x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 3 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 3 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=9219)          [repeated 10x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# Round 4 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 4 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# (ClientAppActor pid=9221)          [repeated 14x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 7x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 5 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 5 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=9221)          [repeated 12x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=9219)
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=9219)             entirely in future versions of Flower.
# (ClientAppActor pid=9219)
# Round 6 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 6 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9221)          [repeated 16x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 7 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 7 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9221)          [repeated 12x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=9219)          [repeated 10x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 8 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 8 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9221)          [repeated 14x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 7x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=9221)          [repeated 6x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 9 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 9 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 10 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 10 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=9221)          [repeated 10x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# Round 11 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 11 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 12 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 12 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 13 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 13 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 14 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 14 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 15 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 15 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9219)          [repeated 12x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 16 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 16 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 8x across cluster]
# (ClientAppActor pid=9219)          [repeated 16x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 8x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 8x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 17 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 17 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9221)          [repeated 14x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 7x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=9221)          [repeated 12x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 18 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 18 aggregated accuracy: 0.2973
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9219)          [repeated 14x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 7x across cluster]
# (ClientAppActor pid=9221) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 8x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: no clients selected, cancel
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# Round 19 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 19 aggregated accuracy: 0.2973
# (ClientAppActor pid=9221) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 7x across cluster]
# (ClientAppActor pid=9221)          [repeated 14x across cluster]
# (ClientAppActor pid=9221)             This is a deprecated feature. It will be removed [repeated 7x across cluster]
# (ClientAppActor pid=9221)             entirely in future versions of Flower. [repeated 7x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 7x across cluster]
# (ClientAppActor pid=9219) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=9219)          [repeated 10x across cluster]
# (ClientAppActor pid=9219)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=9219)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=9219) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 206.97s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06338212015628815
# INFO :      		round 2: 0.06338212015628815
# INFO :      		round 3: 0.06338212015628815
# INFO :      		round 4: 0.06338212015628815
# INFO :      		round 5: 0.06338212015628815
# INFO :      		round 6: 0.06338212015628815
# INFO :      		round 7: 0.06338212015628815
# INFO :      		round 8: 0.06338212015628815
# INFO :      		round 9: 0.06338212015628815
# INFO :      		round 10: 0.06338212015628815
# INFO :      		round 11: 0.06338212015628815
# INFO :      		round 12: 0.06338212015628815
# INFO :      		round 13: 0.06338212015628815
# INFO :      		round 14: 0.06338212015628815
# INFO :      		round 15: 0.06338212015628815
# INFO :      		round 16: 0.06338212015628815
# INFO :      		round 17: 0.06338212015628815
# INFO :      		round 18: 0.06338212015628815
# INFO :      		round 19: 0.06338212015628815
# INFO :      		round 20: 0.06338212015628815
# INFO :
# Round 20 client accuracies:
#   Client 10892504397625728372: accuracy = 0.3120 (prev: 0.312, participated)
#   Client 15042521525871969850: accuracy = 0.2800 (prev: 0.28, participated)
#   Client 4575084854179807627: accuracy = 0.3160 (prev: 0.316, participated)
#   Client 13624414457441813354: accuracy = 0.2870 (prev: 0.287, participated)
#   Client 10344505357825835331: accuracy = 0.2920 (prev: 0.292, participated)
#   Client 15054063207148904620: accuracy = 0.2740 (prev: 0.274, participated)
#   Client 6052036123941770588: accuracy = 0.3200 (prev: 0.32, participated)
#   Client 16306295208814201252: accuracy = 0.3040 (prev: 0.304, participated)
#   Client 4372068911019174871: accuracy = 0.2900 (prev: 0.29, participated)
#   Client 6010294342599894056: accuracy = 0.2980 (prev: 0.298, participated)
# Round 20 aggregated accuracy: 0.2973

# %% [markdown]
# # **Method 5: Top-K Client Selection**
#
# This method selects a fixed number (K=3) of clients per round, either randomly or based on the lowest accuracies, to balance diversity and focus in training.

# %%
# If no clients are selected select K clients for training
import random
from typing import Dict, List, Optional, Tuple

import flwr as fl
from flwr.common import (
    Parameters,
    Scalar,
    FitIns,
    FitRes,
    EvaluateRes,
)
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy

class New(fl.server.strategy.FedAvg):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.client_accuracies: Dict[str, float] = {}
        self.previous_client_accuracies: Dict[str, Optional[float]] = {}
        self.communication_count = 0
        self.terminated = False

    def initialize_clients(self, client_manager: ClientManager):
        for client_proxy in client_manager.all().values():
            cid = client_proxy.cid
            # Initialize previous accuracies to None
            self.previous_client_accuracies[cid] = None
            self.client_accuracies[cid] = 0.0

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, FitIns]]:
        if self.terminated:
            return []

        if server_round == 1:
            self.initialize_clients(client_manager)

        all_clients = list(client_manager.all().values())
        selected_clients = []

        print(f"\nRound {server_round}:")
        for client in all_clients:
            cid = client.cid

            current_accuracy = self.client_accuracies.get(cid, 0.0)
            previous_accuracy = self.previous_client_accuracies.get(cid)

            # Determine if the client is underperforming
            if previous_accuracy is None:
                # First round, consider all clients as underperforming
                underperforming = True
            else:
                if current_accuracy <= previous_accuracy:
                    underperforming = True
                else:
                    underperforming = False

            if underperforming:
                # Client is underperforming, select for training
                print(f"  Client {cid}: Underperforming (prev: {previous_accuracy}, current: {current_accuracy}), selected")
                selected_clients.append(client)
            else:
                # Client is performing well, do not select for training
                print(f"  Client {cid}: Performing well (prev: {previous_accuracy}, current: {current_accuracy}), not selected")

        if not selected_clients:
            print("No clients selected based on criteria.")

            # Option 1: Randomly select k clients
            k = 3  # Adjust k as needed
            selected_clients = random.sample(all_clients, k)
            print(f"  Randomly selected {k} clients.")

            # Option 2: Select top-k clients with the lowest accuracies
            # Uncomment the following lines to use Option (ii)
            """
            k = 3  # Adjust k as needed
            clients_sorted = sorted(all_clients, key=lambda c: self.client_accuracies.get(c.cid, 0.0))
            selected_clients = clients_sorted[:k]
            print(f"  Selected top-{k} clients with the lowest accuracies.")
            """

        self.communication_count += len(selected_clients)
        print(f"  Number of clients selected: {len(selected_clients)}")

        # Prepare fit instructions
        config = {}
        fit_ins = FitIns(parameters, config)
        return [(client, fit_ins) for client in selected_clients]

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        # Call super to aggregate parameters as usual
        aggregated_parameters, aggregated_metrics = super().aggregate_fit(server_round, results, failures)
        if aggregated_parameters is not None:
            self.latest_parameters = aggregated_parameters
        return aggregated_parameters, aggregated_metrics

    def aggregate_evaluate(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, EvaluateRes]],
        failures: List[BaseException],
    ) -> Optional[float]:
        metrics = []
        participating_cids = [client_proxy.cid for client_proxy, _ in results]

        for client_proxy, evaluate_res in results:
            cid = client_proxy.cid
            num_examples = evaluate_res.num_examples
            accuracy = evaluate_res.metrics.get("accuracy", 0.0)

            # Update previous accuracy
            self.previous_client_accuracies[cid] = self.client_accuracies.get(cid, 0.0)
            # Update current accuracy
            self.client_accuracies[cid] = accuracy

            metrics.append((num_examples, {"accuracy": accuracy}))

        print(f"\nRound {server_round} client accuracies:")
        for cid in self.client_accuracies.keys():
            current_accuracy = self.client_accuracies[cid]
            previous_accuracy = self.previous_client_accuracies[cid]
            status = "participated" if cid in participating_cids else "did not participate"
            print(f"  Client {cid}: accuracy = {current_accuracy:.4f} (prev: {previous_accuracy}, {status})")

        aggregated_metrics = self.weighted_average(metrics)
        global_accuracy = aggregated_metrics["accuracy"]
        print(f"Round {server_round} aggregated accuracy: {global_accuracy:.4f}")

        return super().aggregate_evaluate(server_round, results, failures)

    @staticmethod
    def weighted_average(metrics: List[Tuple[int, Dict[str, Scalar]]]) -> Dict[str, Scalar]:
        accuracies = [num_examples * m["accuracy"] for num_examples, m in metrics]
        examples = [num_examples for num_examples, _ in metrics]
        if sum(examples) == 0:
            return {"accuracy": 0.0}
        return {"accuracy": sum(accuracies) / sum(examples)}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
NUM_CLIENTS = 10
NUM_ROUNDS = 20

strategy5 = New(
    fraction_fit=1.0,         # All clients are considered in selection
    min_fit_clients=1,        # At least one client should be available
    min_available_clients=NUM_CLIENTS,
)

# %%
server_config5 = ServerConfig(num_rounds=NUM_ROUNDS)

# Start the simulation
history = fl.simulation.start_simulation(
    client_fn=client_fn,
    num_clients=NUM_CLIENTS,
    client_resources={"num_gpus": 0.5 if torch.cuda.is_available() else 0},
    config=server_config5,
    strategy=strategy5,
)
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# 2024-11-26 11:28:41,781	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:172.28.0.12': 1.0, 'node:__internal_head__': 1.0, 'CPU': 2.0, 'memory': 7981259982.0, 'object_store_memory': 3990629990.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# <ipython-input-14-d371e0ccd979>:4: UserWarning: No `num_cpus` specified in `client_resources`. Using `num_cpus=1` for each client.
#   history = fl.simulation.start_simulation(
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_gpus': 0, 'num_cpus': 1}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=18498) 2024-11-26 11:28:46.653527: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=18498) 2024-11-26 11:28:46.690023: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=18498) 2024-11-26 11:28:46.701947: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=18498) 2024-11-26 11:28:49.125863: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=18498) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=18498) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=18498) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=18498) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=18498) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=18498)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (pid=18497) 2024-11-26 11:28:46.744259: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=18497) 2024-11-26 11:28:46.798353: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=18497) 2024-11-26 11:28:46.813892: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=18497) 2024-11-26 11:28:49.309382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating train split:  14%|█▍        | 7100/50000 [00:00<00:00, 70000.37 examples/s]
# Generating train split:  32%|███▏      | 15800/50000 [00:00<00:00, 79266.15 examples/s]
# Generating train split:  50%|████▉     | 24800/50000 [00:00<00:00, 83557.06 examples/s]
# Generating train split:  67%|██████▋   | 33700/50000 [00:00<00:00, 85254.69 examples/s]
# Generating train split: 100%|██████████| 50000/50000 [00:00<00:00, 83902.26 examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 90436.58 examples/s]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)
# Round 1:
#   Client 17902201588696226740: Underperforming (prev: None, current: 0.0), selected
#   Client 11379625503450858752: Underperforming (prev: None, current: 0.0), selected
#   Client 4257556833612145428: Underperforming (prev: None, current: 0.0), selected
#   Client 9999993343942609094: Underperforming (prev: None, current: 0.0), selected
#   Client 10987555097583255405: Underperforming (prev: None, current: 0.0), selected
#   Client 13596931683633226510: Underperforming (prev: None, current: 0.0), selected
#   Client 17058428006822254229: Underperforming (prev: None, current: 0.0), selected
#   Client 11152687198164533792: Underperforming (prev: None, current: 0.0), selected
#   Client 6744161163515617028: Underperforming (prev: None, current: 0.0), selected
#   Client 11467356516771683302: Underperforming (prev: None, current: 0.0), selected
#   Number of clients selected: 10
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)
# (ClientAppActor pid=18497) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=18497) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=18497) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=18497) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=18497) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=18497)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18497)
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 10 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18498)          [repeated 4x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 12x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 1 client accuracies:
#   Client 17902201588696226740: accuracy = 0.3450 (prev: 0.0, participated)
#   Client 11379625503450858752: accuracy = 0.2940 (prev: 0.0, participated)
#   Client 4257556833612145428: accuracy = 0.3230 (prev: 0.0, participated)
#   Client 9999993343942609094: accuracy = 0.3160 (prev: 0.0, participated)
#   Client 10987555097583255405: accuracy = 0.3140 (prev: 0.0, participated)
#   Client 13596931683633226510: accuracy = 0.2930 (prev: 0.0, participated)
#   Client 17058428006822254229: accuracy = 0.3270 (prev: 0.0, participated)
#   Client 11152687198164533792: accuracy = 0.3170 (prev: 0.0, participated)
#   Client 6744161163515617028: accuracy = 0.2990 (prev: 0.0, participated)
#   Client 11467356516771683302: accuracy = 0.3070 (prev: 0.0, participated)
# Round 1 aggregated accuracy: 0.3135
#
# Round 2:
#   Client 17902201588696226740: Performing well (prev: 0.0, current: 0.345), not selected
#   Client 11379625503450858752: Performing well (prev: 0.0, current: 0.294), not selected
#   Client 4257556833612145428: Performing well (prev: 0.0, current: 0.323), not selected
#   Client 9999993343942609094: Performing well (prev: 0.0, current: 0.316), not selected
#   Client 10987555097583255405: Performing well (prev: 0.0, current: 0.314), not selected
#   Client 13596931683633226510: Performing well (prev: 0.0, current: 0.293), not selected
#   Client 17058428006822254229: Performing well (prev: 0.0, current: 0.327), not selected
#   Client 11152687198164533792: Performing well (prev: 0.0, current: 0.317), not selected
#   Client 6744161163515617028: Performing well (prev: 0.0, current: 0.299), not selected
#   Client 11467356516771683302: Performing well (prev: 0.0, current: 0.307), not selected
# No clients selected based on criteria.
#   Randomly selected 3 clients.
#   Number of clients selected: 3
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)          [repeated 12x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=18497)          [repeated 10x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 2 client accuracies:
#   Client 17902201588696226740: accuracy = 0.3960 (prev: 0.345, participated)
#   Client 11379625503450858752: accuracy = 0.3610 (prev: 0.294, participated)
#   Client 4257556833612145428: accuracy = 0.3830 (prev: 0.323, participated)
#   Client 9999993343942609094: accuracy = 0.3510 (prev: 0.316, participated)
#   Client 10987555097583255405: accuracy = 0.3740 (prev: 0.314, participated)
#   Client 13596931683633226510: accuracy = 0.3550 (prev: 0.293, participated)
#   Client 17058428006822254229: accuracy = 0.3730 (prev: 0.327, participated)
#   Client 11152687198164533792: accuracy = 0.3870 (prev: 0.317, participated)
#   Client 6744161163515617028: accuracy = 0.3590 (prev: 0.299, participated)
#   Client 11467356516771683302: accuracy = 0.3660 (prev: 0.307, participated)
# Round 2 aggregated accuracy: 0.3705
#
# Round 3:
#   Client 17902201588696226740: Performing well (prev: 0.345, current: 0.396), not selected
#   Client 11379625503450858752: Performing well (prev: 0.294, current: 0.361), not selected
#   Client 4257556833612145428: Performing well (prev: 0.323, current: 0.383), not selected
#   Client 9999993343942609094: Performing well (prev: 0.316, current: 0.351), not selected
#   Client 10987555097583255405: Performing well (prev: 0.314, current: 0.374), not selected
#   Client 13596931683633226510: Performing well (prev: 0.293, current: 0.355), not selected
#   Client 17058428006822254229: Performing well (prev: 0.327, current: 0.373), not selected
#   Client 11152687198164533792: Performing well (prev: 0.317, current: 0.387), not selected
#   Client 6744161163515617028: Performing well (prev: 0.299, current: 0.359), not selected
#   Client 11467356516771683302: Performing well (prev: 0.307, current: 0.366), not selected
# No clients selected based on criteria.
#   Randomly selected 3 clients.
#   Number of clients selected: 3
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=18497)          [repeated 10x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)          [repeated 2x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)          [repeated 4x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 3 client accuracies:
#   Client 17902201588696226740: accuracy = 0.4260 (prev: 0.396, participated)
#   Client 11379625503450858752: accuracy = 0.3820 (prev: 0.361, participated)
#   Client 4257556833612145428: accuracy = 0.4160 (prev: 0.383, participated)
#   Client 9999993343942609094: accuracy = 0.3840 (prev: 0.351, participated)
#   Client 10987555097583255405: accuracy = 0.3890 (prev: 0.374, participated)
#   Client 13596931683633226510: accuracy = 0.3940 (prev: 0.355, participated)
#   Client 17058428006822254229: accuracy = 0.4100 (prev: 0.373, participated)
#   Client 11152687198164533792: accuracy = 0.4240 (prev: 0.387, participated)
#   Client 6744161163515617028: accuracy = 0.3890 (prev: 0.359, participated)
#   Client 11467356516771683302: accuracy = 0.3760 (prev: 0.366, participated)
# Round 3 aggregated accuracy: 0.3990
#
# Round 4:
#   Client 17902201588696226740: Performing well (prev: 0.396, current: 0.426), not selected
#   Client 11379625503450858752: Performing well (prev: 0.361, current: 0.382), not selected
#   Client 4257556833612145428: Performing well (prev: 0.383, current: 0.416), not selected
#   Client 9999993343942609094: Performing well (prev: 0.351, current: 0.384), not selected
#   Client 10987555097583255405: Performing well (prev: 0.374, current: 0.389), not selected
#   Client 13596931683633226510: Performing well (prev: 0.355, current: 0.394), not selected
#   Client 17058428006822254229: Performing well (prev: 0.373, current: 0.41), not selected
#   Client 11152687198164533792: Performing well (prev: 0.387, current: 0.424), not selected
#   Client 6744161163515617028: Performing well (prev: 0.359, current: 0.389), not selected
#   Client 11467356516771683302: Performing well (prev: 0.366, current: 0.376), not selected
# No clients selected based on criteria.
#   Randomly selected 3 clients.
#   Number of clients selected: 3
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 10x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=18498)          [repeated 6x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 4 client accuracies:
#   Client 17902201588696226740: accuracy = 0.4290 (prev: 0.426, participated)
#   Client 11379625503450858752: accuracy = 0.4060 (prev: 0.382, participated)
#   Client 4257556833612145428: accuracy = 0.4400 (prev: 0.416, participated)
#   Client 9999993343942609094: accuracy = 0.4140 (prev: 0.384, participated)
#   Client 10987555097583255405: accuracy = 0.4130 (prev: 0.389, participated)
#   Client 13596931683633226510: accuracy = 0.4120 (prev: 0.394, participated)
#   Client 17058428006822254229: accuracy = 0.4130 (prev: 0.41, participated)
#   Client 11152687198164533792: accuracy = 0.4340 (prev: 0.424, participated)
#   Client 6744161163515617028: accuracy = 0.4060 (prev: 0.389, participated)
#   Client 11467356516771683302: accuracy = 0.4140 (prev: 0.376, participated)
# Round 4 aggregated accuracy: 0.4181
#
# Round 5:
#   Client 17902201588696226740: Performing well (prev: 0.426, current: 0.429), not selected
#   Client 11379625503450858752: Performing well (prev: 0.382, current: 0.406), not selected
#   Client 4257556833612145428: Performing well (prev: 0.416, current: 0.44), not selected
#   Client 9999993343942609094: Performing well (prev: 0.384, current: 0.414), not selected
#   Client 10987555097583255405: Performing well (prev: 0.389, current: 0.413), not selected
#   Client 13596931683633226510: Performing well (prev: 0.394, current: 0.412), not selected
#   Client 17058428006822254229: Performing well (prev: 0.41, current: 0.413), not selected
#   Client 11152687198164533792: Performing well (prev: 0.424, current: 0.434), not selected
#   Client 6744161163515617028: Performing well (prev: 0.389, current: 0.406), not selected
#   Client 11467356516771683302: Performing well (prev: 0.376, current: 0.414), not selected
# No clients selected based on criteria.
#   Randomly selected 3 clients.
#   Number of clients selected: 3
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=18497)          [repeated 8x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)          [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18498)          [repeated 10x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 5 client accuracies:
#   Client 17902201588696226740: accuracy = 0.4530 (prev: 0.429, participated)
#   Client 11379625503450858752: accuracy = 0.4280 (prev: 0.406, participated)
#   Client 4257556833612145428: accuracy = 0.4590 (prev: 0.44, participated)
#   Client 9999993343942609094: accuracy = 0.4180 (prev: 0.414, participated)
#   Client 10987555097583255405: accuracy = 0.4300 (prev: 0.413, participated)
#   Client 13596931683633226510: accuracy = 0.4410 (prev: 0.412, participated)
#   Client 17058428006822254229: accuracy = 0.4380 (prev: 0.413, participated)
#   Client 11152687198164533792: accuracy = 0.4620 (prev: 0.434, participated)
#   Client 6744161163515617028: accuracy = 0.4370 (prev: 0.406, participated)
#   Client 11467356516771683302: accuracy = 0.4300 (prev: 0.414, participated)
# Round 5 aggregated accuracy: 0.4396
#
# Round 6:
#   Client 17902201588696226740: Performing well (prev: 0.429, current: 0.453), not selected
#   Client 11379625503450858752: Performing well (prev: 0.406, current: 0.428), not selected
#   Client 4257556833612145428: Performing well (prev: 0.44, current: 0.459), not selected
#   Client 9999993343942609094: Performing well (prev: 0.414, current: 0.418), not selected
#   Client 10987555097583255405: Performing well (prev: 0.413, current: 0.43), not selected
#   Client 13596931683633226510: Performing well (prev: 0.412, current: 0.441), not selected
#   Client 17058428006822254229: Performing well (prev: 0.413, current: 0.438), not selected
#   Client 11152687198164533792: Performing well (prev: 0.434, current: 0.462), not selected
#   Client 6744161163515617028: Performing well (prev: 0.406, current: 0.437), not selected
#   Client 11467356516771683302: Performing well (prev: 0.414, current: 0.43), not selected
# No clients selected based on criteria.
#   Randomly selected 3 clients.
#   Number of clients selected: 3
# (ClientAppActor pid=18497)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=18498)          [repeated 6x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=18497)          [repeated 12x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 4 clients (out of 10)
# Round 6 client accuracies:
#   Client 17902201588696226740: accuracy = 0.4420 (prev: 0.453, participated)
#   Client 11379625503450858752: accuracy = 0.4390 (prev: 0.428, participated)
#   Client 4257556833612145428: accuracy = 0.4580 (prev: 0.459, participated)
#   Client 9999993343942609094: accuracy = 0.4290 (prev: 0.418, participated)
#   Client 10987555097583255405: accuracy = 0.4280 (prev: 0.43, participated)
#   Client 13596931683633226510: accuracy = 0.4450 (prev: 0.441, participated)
#   Client 17058428006822254229: accuracy = 0.4460 (prev: 0.438, participated)
#   Client 11152687198164533792: accuracy = 0.4700 (prev: 0.462, participated)
#   Client 6744161163515617028: accuracy = 0.4250 (prev: 0.437, participated)
#   Client 11467356516771683302: accuracy = 0.4330 (prev: 0.43, participated)
# Round 6 aggregated accuracy: 0.4415
#
# Round 7:
#   Client 17902201588696226740: Underperforming (prev: 0.453, current: 0.442), selected
#   Client 11379625503450858752: Performing well (prev: 0.428, current: 0.439), not selected
#   Client 4257556833612145428: Underperforming (prev: 0.459, current: 0.458), selected
#   Client 9999993343942609094: Performing well (prev: 0.418, current: 0.429), not selected
#   Client 10987555097583255405: Underperforming (prev: 0.43, current: 0.428), selected
#   Client 13596931683633226510: Performing well (prev: 0.441, current: 0.445), not selected
#   Client 17058428006822254229: Performing well (prev: 0.438, current: 0.446), not selected
#   Client 11152687198164533792: Performing well (prev: 0.462, current: 0.47), not selected
#   Client 6744161163515617028: Underperforming (prev: 0.437, current: 0.425), selected
#   Client 11467356516771683302: Performing well (prev: 0.43, current: 0.433), not selected
#   Number of clients selected: 4
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=18498)          [repeated 8x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 4 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18497)             entirely in future versions of Flower.
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=18497)          [repeated 10x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 3x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 7 client accuracies:
#   Client 17902201588696226740: accuracy = 0.4780 (prev: 0.442, participated)
#   Client 11379625503450858752: accuracy = 0.4510 (prev: 0.439, participated)
#   Client 4257556833612145428: accuracy = 0.4830 (prev: 0.458, participated)
#   Client 9999993343942609094: accuracy = 0.4370 (prev: 0.429, participated)
#   Client 10987555097583255405: accuracy = 0.4370 (prev: 0.428, participated)
#   Client 13596931683633226510: accuracy = 0.4630 (prev: 0.445, participated)
#   Client 17058428006822254229: accuracy = 0.4620 (prev: 0.446, participated)
#   Client 11152687198164533792: accuracy = 0.4890 (prev: 0.47, participated)
#   Client 6744161163515617028: accuracy = 0.4620 (prev: 0.425, participated)
#   Client 11467356516771683302: accuracy = 0.4770 (prev: 0.433, participated)
# Round 7 aggregated accuracy: 0.4639
#
# Round 8:
#   Client 17902201588696226740: Performing well (prev: 0.442, current: 0.478), not selected
#   Client 11379625503450858752: Performing well (prev: 0.439, current: 0.451), not selected
#   Client 4257556833612145428: Performing well (prev: 0.458, current: 0.483), not selected
#   Client 9999993343942609094: Performing well (prev: 0.429, current: 0.437), not selected
#   Client 10987555097583255405: Performing well (prev: 0.428, current: 0.437), not selected
# ...
# (ClientAppActor pid=18498)          [repeated 4x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 6 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=18498)          [repeated 10x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Round 18 client accuracies:
#   Client 17902201588696226740: accuracy = 0.5540 (prev: 0.552, participated)
#   Client 11379625503450858752: accuracy = 0.5320 (prev: 0.519, participated)
#   Client 4257556833612145428: accuracy = 0.5690 (prev: 0.549, participated)
#   Client 9999993343942609094: accuracy = 0.5200 (prev: 0.505, participated)
#   Client 10987555097583255405: accuracy = 0.5470 (prev: 0.532, participated)
#   Client 13596931683633226510: accuracy = 0.5240 (prev: 0.533, participated)
#   Client 17058428006822254229: accuracy = 0.5420 (prev: 0.533, participated)
#   Client 11152687198164533792: accuracy = 0.5740 (prev: 0.577, participated)
#   Client 6744161163515617028: accuracy = 0.5470 (prev: 0.526, participated)
#   Client 11467356516771683302: accuracy = 0.5180 (prev: 0.518, participated)
# Round 18 aggregated accuracy: 0.5427
#
# Round 19:
#   Client 17902201588696226740: Performing well (prev: 0.552, current: 0.554), not selected
#   Client 11379625503450858752: Performing well (prev: 0.519, current: 0.532), not selected
#   Client 4257556833612145428: Performing well (prev: 0.549, current: 0.569), not selected
#   Client 9999993343942609094: Performing well (prev: 0.505, current: 0.52), not selected
#   Client 10987555097583255405: Performing well (prev: 0.532, current: 0.547), not selected
#   Client 13596931683633226510: Underperforming (prev: 0.533, current: 0.524), selected
#   Client 17058428006822254229: Performing well (prev: 0.533, current: 0.542), not selected
#   Client 11152687198164533792: Underperforming (prev: 0.577, current: 0.574), selected
#   Client 6744161163515617028: Performing well (prev: 0.526, current: 0.547), not selected
#   Client 11467356516771683302: Underperforming (prev: 0.518, current: 0.518), selected
#   Number of clients selected: 3
# (ClientAppActor pid=18497)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=18498)          [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=18498)             entirely in future versions of Flower.
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 6 clients (out of 10)
# Round 19 client accuracies:
#   Client 17902201588696226740: accuracy = 0.5500 (prev: 0.554, participated)
#   Client 11379625503450858752: accuracy = 0.5460 (prev: 0.532, participated)
#   Client 4257556833612145428: accuracy = 0.5650 (prev: 0.569, participated)
#   Client 9999993343942609094: accuracy = 0.5190 (prev: 0.52, participated)
#   Client 10987555097583255405: accuracy = 0.5330 (prev: 0.547, participated)
#   Client 13596931683633226510: accuracy = 0.5300 (prev: 0.524, participated)
#   Client 17058428006822254229: accuracy = 0.5370 (prev: 0.542, participated)
#   Client 11152687198164533792: accuracy = 0.5780 (prev: 0.574, participated)
#   Client 6744161163515617028: accuracy = 0.5310 (prev: 0.547, participated)
#   Client 11467356516771683302: accuracy = 0.5190 (prev: 0.518, participated)
# Round 19 aggregated accuracy: 0.5408
#
# Round 20:
#   Client 17902201588696226740: Underperforming (prev: 0.554, current: 0.55), selected
#   Client 11379625503450858752: Performing well (prev: 0.532, current: 0.546), not selected
#   Client 4257556833612145428: Underperforming (prev: 0.569, current: 0.565), selected
#   Client 9999993343942609094: Underperforming (prev: 0.52, current: 0.519), selected
#   Client 10987555097583255405: Underperforming (prev: 0.547, current: 0.533), selected
#   Client 13596931683633226510: Performing well (prev: 0.524, current: 0.53), not selected
#   Client 17058428006822254229: Underperforming (prev: 0.542, current: 0.537), selected
#   Client 11152687198164533792: Performing well (prev: 0.574, current: 0.578), not selected
#   Client 6744161163515617028: Underperforming (prev: 0.547, current: 0.531), selected
#   Client 11467356516771683302: Performing well (prev: 0.518, current: 0.519), not selected
#   Number of clients selected: 6
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18497)          [repeated 10x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=18497) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18497)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18497)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18497)          [repeated 4x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 6 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=18498)          [repeated 4x across cluster]
# (ClientAppActor pid=18498) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=18498) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=18498)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=18498)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=18498)          [repeated 12x across cluster]
# (ClientAppActor pid=18497) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 514.14s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06275970349311828
# INFO :      		round 2: 0.055776019752025605
# INFO :      		round 3: 0.05261657062768936
# INFO :      		round 4: 0.05079123148918152
# INFO :      		round 5: 0.04916897509098053
# INFO :      		round 6: 0.04866178113222122
# INFO :      		round 7: 0.04698425745368004
# INFO :      		round 8: 0.046489600986242295
# INFO :      		round 9: 0.04691168156266212
# INFO :      		round 10: 0.04488049539327622
# INFO :      		round 11: 0.04498217895030975
# INFO :      		round 12: 0.04430950233340263
# INFO :      		round 13: 0.04398472581505775
# INFO :      		round 14: 0.042903703397512434
# INFO :      		round 15: 0.04473161989450455
# INFO :      		round 16: 0.04205634307265282
# INFO :      		round 17: 0.04211395641565323
# INFO :      		round 18: 0.04149923042654991
# INFO :      		round 19: 0.04138880119919777
# INFO :      		round 20: 0.040712876105308535
# INFO :
# Round 20 client accuracies:
#   Client 17902201588696226740: accuracy = 0.5710 (prev: 0.55, participated)
#   Client 11379625503450858752: accuracy = 0.5380 (prev: 0.546, participated)
#   Client 4257556833612145428: accuracy = 0.5560 (prev: 0.565, participated)
#   Client 9999993343942609094: accuracy = 0.5190 (prev: 0.519, participated)
#   Client 10987555097583255405: accuracy = 0.5410 (prev: 0.533, participated)
#   Client 13596931683633226510: accuracy = 0.5330 (prev: 0.53, participated)
#   Client 17058428006822254229: accuracy = 0.5360 (prev: 0.537, participated)
#   Client 11152687198164533792: accuracy = 0.5940 (prev: 0.578, participated)
#   Client 6744161163515617028: accuracy = 0.5460 (prev: 0.531, participated)
#   Client 11467356516771683302: accuracy = 0.5220 (prev: 0.519, participated)
# Round 20 aggregated accuracy: 0.5456

# %% [markdown]
# # **Method 6: Dynamic K and Alpha Selection**
#
# This method dynamically adjusts client participation using K and alpha parameters to balance exploration and exploitation, optimizing accuracy and communication efficiency.

# %%
# Install required packages
# !pip install -q flwr[simulation] flwr-datasets[vision] torch torchvision matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 MB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 73.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 8.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 72.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 24.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
# Import Necessary Lib
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from collections import OrderedDict
from typing import List, Tuple, Dict, Optional

from datasets.utils.logging import disable_progress_bar
from torch.utils.data import DataLoader

import flwr as fl
from flwr.client import Client, NumPyClient
from flwr.common import (
    Metrics,
    Parameters,
    Scalar,
    FitIns,
    FitRes,
    EvaluateRes,
    Config,
)
from flwr.server import ServerConfig
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import FedAvg
from flwr.common.logger import log
from logging import INFO
from flwr_datasets import FederatedDataset

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Device configuration
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training on {DEVICE}")


disable_progress_bar()
# Out:
# Training on cpu

# %%
# Global constants
NUM_CLIENTS = 10
NUM_ROUNDS = 20
BATCH_SIZE = 32
INITIAL_ROUNDS = 5  # Minimum number of rounds for initial selection
K = 3  # Number of clients to select per round
ALPHA_VALUES = [0.5, 0.2, 0.1]  # Different alpha values for experimentation

# %%
# Function to load Cifar10 dataset
def load_datasets(partition_id: int):
    fds = FederatedDataset(dataset="cifar10", partitioners={"train": NUM_CLIENTS})
    partition = fds.load_partition(partition_id)
    # Divide data on each node: 80% train, 20% test
    partition_train_test = partition.train_test_split(test_size=0.2, seed=42)
    pytorch_transforms = transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]
    )

    def apply_transforms(batch):
        batch["img"] = [pytorch_transforms(img) for img in batch["img"]]
        return batch

    # Create train/val for each partition and wrap it into DataLoader
    partition_train_test = partition_train_test.with_transform(apply_transforms)
    trainloader = DataLoader(
        partition_train_test["train"], batch_size=BATCH_SIZE, shuffle=True
    )
    valloader = DataLoader(partition_train_test["test"], batch_size=BATCH_SIZE)
    testset = fds.load_split("test").with_transform(apply_transforms)
    testloader = DataLoader(testset, batch_size=BATCH_SIZE)
    return trainloader, valloader, testloader

# %%
# Model definition for CIFAR10 same as above.
class Net(nn.Module):
    def __init__(self) -> None:
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 5 * 5, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 5 * 5)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
# Training function
def train(net, trainloader, epochs: int):

    criterion = torch.nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters())
    net.train()
    for _ in range(epochs):
        for batch in trainloader:
            images, labels = batch["img"].to(DEVICE), batch["label"].to(DEVICE)
            optimizer.zero_grad()
            outputs = net(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

# Evaluation function
def test(net, testloader):

    criterion = torch.nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0.0
    net.eval()
    with torch.no_grad():
        for batch in testloader:
            images, labels = batch["img"].to(DEVICE), batch["label"].to(DEVICE)
            outputs = net(images)
            loss += criterion(outputs, labels).item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    loss /= len(testloader)
    accuracy = correct / total
    return loss, accuracy

# %%
# Functions to set and get model parameters
def set_parameters(net, parameters: List[np.ndarray]):
    params_dict = zip(net.state_dict().keys(), parameters)
    state_dict = OrderedDict({k: torch.Tensor(v) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)

def get_parameters(net) -> List[np.ndarray]:
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

# %%
# Flower client implementation
class FlowerClient(NumPyClient):
    def __init__(self, cid, net, trainloader, valloader):
        self.cid = cid
        self.net = net
        self.trainloader = trainloader
        self.valloader = valloader

    def get_parameters(self, config: Config) -> List[np.ndarray]:
        return get_parameters(self.net)

    def fit(
        self, parameters: List[np.ndarray], config: Config
    ) -> Tuple[List[np.ndarray], int, Dict]:
        set_parameters(self.net, parameters)
        train(self.net, self.trainloader, epochs=1)
        return get_parameters(self.net), len(self.trainloader.dataset), {}

    def evaluate(
        self, parameters: List[np.ndarray], config: Config
    ) -> Tuple[float, int, Dict]:
        set_parameters(self.net, parameters)
        loss, accuracy = test(self.net, self.valloader)
        return float(loss), len(self.valloader.dataset), {"accuracy": float(accuracy)}

    def to_client(self) -> Client:

        return super().to_client()

# %%
from flwr.common import Context
# Client function
def client_fn(cid: str) -> Client:

    # Load model
    net = Net().to(DEVICE)
    # Load data
    partition_id = int(cid)
    trainloader, valloader, _ = load_datasets(partition_id)
    # Create and return the Flower client
    return FlowerClient(cid, net, trainloader, valloader).to_client()

# %% [markdown]
# Strategy for Method 6

# %%
from flwr.common import (
    EvaluateIns,
    EvaluateRes,
    FitIns,
    FitRes,
    Parameters,
    Scalar,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
)
from typing import Dict, List, Optional, Tuple
import numpy as np
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import Strategy
from flwr.common.logger import log
from logging import INFO, WARNING, ERROR

class CS_final(Strategy):
    def __init__(
        self,
        fraction_fit: float = 1.0,
        fraction_evaluate: float = 1.0,
        min_fit_clients: int = 2,
        min_evaluate_clients: int = 2,
        min_available_clients: int = 2,
        evaluate_fn=None,
        on_fit_config_fn=None,
        on_evaluate_config_fn=None,
        accept_failures: bool = True,
        initial_rounds: int = 5,  # Minimum number of initial rounds
        k: int = 3,               # Number of clients to select per round
        alpha: float = 0.5,       # Smoothing factor for selection probability
        total_rounds: int = 20,   # Total number of rounds
    ):
        super().__init__()
        self.fraction_fit = fraction_fit
        self.fraction_evaluate = fraction_evaluate
        self.min_fit_clients = min_fit_clients
        self.min_evaluate_clients = min_evaluate_clients
        self.min_available_clients = min_available_clients
        self.evaluate_fn = evaluate_fn
        self.on_fit_config_fn = on_fit_config_fn
        self.on_evaluate_config_fn = on_evaluate_config_fn
        self.accept_failures = accept_failures

        self.initial_rounds = initial_rounds
        self.k = k
        self.alpha = alpha
        self.client_accuracies: Dict[str, float] = {}
        self.current_round = 0
        self.parameters: Optional[Parameters] = None  # Will be set after initialization
        self.global_accuracy: float = 0.0  # Store global model accuracy

        self.total_rounds = total_rounds  # To record communication rounds
        self.total_communications = 0     # Initialize total communications

        # Track clients selected in initial rounds to ensure all participate at least once
        self.initial_selected_clients: set = set()

    def initialize_parameters(
        self, client_manager: ClientManager
    ) -> Optional[Parameters]:

        # Return None to let the server initialize parameters from a client
        return None

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, FitIns]]:

        self.current_round = server_round
        log(INFO, f"\n[ROUND {server_round}]")

        clients_dict = client_manager.all()
        available_cids = list(clients_dict.keys())

        # Ensure all clients have an accuracy value
        for cid in available_cids:
            if cid not in self.client_accuracies:
                self.client_accuracies[cid] = 0.0  # Default accuracy

        selected_cids = []

        if server_round <= self.initial_rounds:
            # Select top-k least accurate clients that haven't been selected yet
            # Sort clients by least accuracy
            sorted_clients = sorted(
                self.client_accuracies.items(), key=lambda x: x[1]
            )
            # Select clients not yet selected
            available_for_selection = [
                cid for cid, _ in sorted_clients if cid not in self.initial_selected_clients
            ]
            # Select up to k clients
            for cid, _ in sorted_clients:
                if cid not in self.initial_selected_clients:
                    selected_cids.append(cid)
                    self.initial_selected_clients.add(cid)
                    if len(selected_cids) == self.k:
                        break
            # If not enough unique clients, fill the rest with top-k least accurate
            if len(selected_cids) < self.k:
                additional = self.k - len(selected_cids)
                for cid, _ in sorted_clients:
                    if cid not in selected_cids:
                        selected_cids.append(cid)
                        if len(selected_cids) == self.k:
                            break
            log(
                INFO,
                f"Round {server_round}: Initial selection - Selected clients {selected_cids}",
            )
        else:
            # Probabilistic selection based on 1 - alpha * accuracy
            probabilities = {}
            for cid in available_cids:
                accuracy = self.client_accuracies[cid]
                prob = max(1 - self.alpha * accuracy, 0.0)
                probabilities[cid] = prob

            # Normalize probabilities
            total_prob = sum(probabilities.values())
            if total_prob == 0:
                # If total_prob is zero, default to uniform probabilities
                for cid in probabilities:
                    probabilities[cid] = 1.0 / len(probabilities)
            else:
                for cid in probabilities:
                    probabilities[cid] /= total_prob

            # Select k unique clients based on probabilities
            selected_cids = list(
                np.random.choice(
                    available_cids,
                    size=self.k,
                    replace=False,
                    p=[probabilities[cid] for cid in available_cids],
                )
            )
            log(
                INFO,
                f"Round {server_round}: Probabilistic selection - Selected clients {selected_cids}",
            )

        # Update total communications
        self.total_communications += len(selected_cids)

        clients = [
            clients_dict.get(cid) for cid in selected_cids if clients_dict.get(cid) is not None
        ]

        # Create fit instructions
        config = self.on_fit_config_fn(server_round) if self.on_fit_config_fn else {}
        fit_ins = FitIns(parameters, config)

        # Return client configurations as a list
        return [(client, fit_ins) for client in clients if client is not None]

    def configure_evaluate(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, EvaluateIns]]:

        # Evaluate on all clients
        clients = list(client_manager.all().values())

        # Create evaluate instructions
        config = (
            self.on_evaluate_config_fn(server_round)
            if self.on_evaluate_config_fn
            else {}
        )
        evaluate_ins = EvaluateIns(parameters, config)

        # Return client configurations as a list of (ClientProxy, EvaluateIns)
        return [(client, evaluate_ins) for client in clients if client is not None]

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:

        if not results:
            return None, {}

        # Total number of examples used for training
        total_examples = sum([res.num_examples for _, res in results])

        # Initialize the list to store weighted updates
        weighted_updates = []

        for _, fit_res in results:
            # Deserialize parameters to ndarrays
            client_weights = parameters_to_ndarrays(fit_res.parameters)
            # Calculate the weight based on the number of examples
            num_examples = fit_res.num_examples
            weight = num_examples / total_examples
            # Append the weighted client weights
            weighted_updates.append([layer * weight for layer in client_weights])

        # Sum the weighted updates
        aggregated_weights = [
            np.sum([update[layer] for update in weighted_updates], axis=0)
            for layer in range(len(weighted_updates[0]))
        ]

        # Serialize aggregated weights back to Parameters
        aggregated_parameters = ndarrays_to_parameters(aggregated_weights)

        # Return aggregated parameters and an empty metrics dictionary
        return aggregated_parameters, {}

    def aggregate_evaluate(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, EvaluateRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[float], Dict[str, Scalar]]:

        if not results:
            return None, {}

        # Compute weighted loss
        losses = [res.num_examples * res.loss for _, res in results]
        examples = [res.num_examples for _, res in results]
        aggregated_loss = sum(losses) / sum(examples)

        # Compute weighted accuracy
        accuracies = [
            res.num_examples * res.metrics.get("accuracy", 0.0)
            for _, res in results
        ]
        aggregated_accuracy = sum(accuracies) / sum(examples)
        self.global_accuracy = aggregated_accuracy  # Store global accuracy

        # Update client accuracies
        for client_proxy, eval_res in results:
            cid = client_proxy.cid  # Correctly retrieve the client ID
            accuracy = eval_res.metrics.get("accuracy", 0.0)
            prev_accuracy = self.client_accuracies.get(cid, 0.0)
            self.client_accuracies[cid] = accuracy

            # Log client accuracies
            log(
                INFO,
                f"Client {cid}: accuracy = {accuracy:.4f} (prev: {prev_accuracy:.4f})",
            )

        # Log aggregated accuracy
        log(
            INFO,
            f"Round {server_round} aggregated accuracy: {aggregated_accuracy:.4f}\n",
        )

        # Print total communications after the last round
        if server_round == self.total_rounds:
            log(
                INFO,
                f"[SUMMARY]\nTotal communication rounds: {self.total_communications}",
            )

        # Return aggregated loss and metrics
        return aggregated_loss, {"accuracy": aggregated_accuracy}

    def evaluate(
        self,
        server_round: int,
        parameters: Parameters,
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        """Evaluate model parameters using an optional validation function."""
        if self.evaluate_fn is None:

            return None
        return self.evaluate_fn(server_round, parameters)

# %%
# Start simulation
if __name__ == "__main__":
    # Iterate over different alpha values for experimentation
    for alpha in ALPHA_VALUES:
        print(f"\nStarting simulation with alpha = {alpha}\n{'='*40}")

        # Create strategy instance
        strategy_strategy_final = CS_final(
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=2,
            min_evaluate_clients=2,
            min_available_clients=2,
            initial_rounds=INITIAL_ROUNDS,
            k=K,
            alpha=alpha,
            total_rounds=20,
        )

        # Start the simulation
        fl.simulation.start_simulation(
            client_fn=client_fn,
            num_clients=NUM_CLIENTS,
            config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
            strategy=strategy_strategy_final,
        )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# Starting simulation with alpha = 0.5
# ========================================
# 2024-12-05 12:52:32,217	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 2.0, 'memory': 7982117684.0, 'object_store_memory': 3991058841.0, 'node:__internal_head__': 1.0, 'node:172.28.0.12': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=2634) 2024-12-05 12:52:37.307085: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2634) 2024-12-05 12:52:37.392692: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2634) 2024-12-05 12:52:37.416676: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2634) 2024-12-05 12:52:41.335874: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2635) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2635) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2635) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2635) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2635) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2635)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (pid=2635) 2024-12-05 12:52:37.344676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2635) 2024-12-05 12:52:37.428169: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2635) 2024-12-05 12:52:37.457330: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2635) 2024-12-05 12:52:41.463602: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating train split:   4%|▎         | 1800/50000 [00:00<00:02, 17311.53 examples/s]
# Generating train split:  10%|▉         | 4800/50000 [00:00<00:01, 24152.52 examples/s]
# Generating train split:  15%|█▌        | 7600/50000 [00:00<00:01, 24825.72 examples/s]
# Generating train split:  22%|██▏       | 11000/50000 [00:00<00:01, 27755.96 examples/s]
# Generating train split:  28%|██▊       | 13800/50000 [00:00<00:01, 26787.89 examples/s]
# Generating train split:  33%|███▎      | 16600/50000 [00:00<00:01, 26768.13 examples/s]
# Generating train split:  40%|███▉      | 19900/50000 [00:00<00:01, 27996.31 examples/s]
# Generating train split:  48%|████▊     | 23900/50000 [00:00<00:00, 27089.06 examples/s]
# Generating train split:  56%|█████▌    | 27800/50000 [00:01<00:00, 29434.93 examples/s]
# Generating train split:  62%|██████▏   | 30900/50000 [00:01<00:00, 22258.30 examples/s]
# Generating train split:  70%|██████▉   | 34900/50000 [00:01<00:00, 23262.61 examples/s]
# Generating train split:  79%|███████▉  | 39400/50000 [00:01<00:00, 24539.49 examples/s]
# Generating train split:  84%|████████▍ | 42100/50000 [00:01<00:00, 21662.72 examples/s]
# Generating train split:  90%|█████████ | 45100/50000 [00:01<00:00, 23387.25 examples/s]
# Generating train split: 100%|██████████| 50000/50000 [00:01<00:00, 25127.93 examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating test split:  28%|██▊       | 2800/10000 [00:00<00:00, 26071.94 examples/s]
# Generating test split:  55%|█████▌    | 5500/10000 [00:00<00:00, 25508.82 examples/s]
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 25672.22 examples/s]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :
# [ROUND 1]
# INFO :      Round 1: Initial selection - Selected clients ['1807278659760480190', '13131094784264262786', '5750641272721686063']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2634) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2634) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2634) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2634) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2634) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2634)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# (ClientAppActor pid=2634)
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# (ClientAppActor pid=2634)
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=2634)          [repeated 8x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 2356968647547109814: accuracy = 0.2980 (prev: 0.0000)
# INFO :      Client 15699243308435604940: accuracy = 0.2950 (prev: 0.0000)
# INFO :      Client 5750641272721686063: accuracy = 0.3270 (prev: 0.0000)
# INFO :      Client 17279947229144345322: accuracy = 0.3010 (prev: 0.0000)
# INFO :      Client 13368760428531285841: accuracy = 0.3200 (prev: 0.0000)
# INFO :      Client 482635144743528460: accuracy = 0.2950 (prev: 0.0000)
# INFO :      Client 1807278659760480190: accuracy = 0.3340 (prev: 0.0000)
# INFO :      Client 13131094784264262786: accuracy = 0.2910 (prev: 0.0000)
# INFO :      Client 13308856144431293940: accuracy = 0.3060 (prev: 0.0000)
# INFO :      Client 15793411968814662437: accuracy = 0.2860 (prev: 0.0000)
# INFO :      Round 1 aggregated accuracy: 0.3053
#
# INFO :
# INFO :      [ROUND 2]
# INFO :
# [ROUND 2]
# INFO :      Round 2: Initial selection - Selected clients ['15793411968814662437', '15699243308435604940', '482635144743528460']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)          [repeated 2x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635)          [repeated 6x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 15699243308435604940: accuracy = 0.3490 (prev: 0.2950)
# INFO :      Client 13368760428531285841: accuracy = 0.3960 (prev: 0.3200)
# INFO :      Client 17279947229144345322: accuracy = 0.3660 (prev: 0.3010)
# INFO :      Client 1807278659760480190: accuracy = 0.4110 (prev: 0.3340)
# INFO :      Client 2356968647547109814: accuracy = 0.3430 (prev: 0.2980)
# INFO :      Client 482635144743528460: accuracy = 0.3500 (prev: 0.2950)
# INFO :      Client 13308856144431293940: accuracy = 0.3580 (prev: 0.3060)
# INFO :      Client 13131094784264262786: accuracy = 0.3740 (prev: 0.2910)
# INFO :      Client 15793411968814662437: accuracy = 0.3460 (prev: 0.2860)
# INFO :      Client 5750641272721686063: accuracy = 0.3990 (prev: 0.3270)
# INFO :      Round 2 aggregated accuracy: 0.3692
#
# INFO :
# INFO :      [ROUND 3]
# INFO :
# [ROUND 3]
# INFO :      Round 3: Initial selection - Selected clients ['2356968647547109814', '13308856144431293940', '17279947229144345322']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2635)          [repeated 10x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635)          [repeated 2x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2635)          [repeated 12x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 482635144743528460: accuracy = 0.3850 (prev: 0.3500)
# INFO :      Client 15699243308435604940: accuracy = 0.3790 (prev: 0.3490)
# INFO :      Client 13368760428531285841: accuracy = 0.4110 (prev: 0.3960)
# INFO :      Client 13131094784264262786: accuracy = 0.3970 (prev: 0.3740)
# INFO :      Client 1807278659760480190: accuracy = 0.4440 (prev: 0.4110)
# INFO :      Client 17279947229144345322: accuracy = 0.3980 (prev: 0.3660)
# INFO :      Client 5750641272721686063: accuracy = 0.4330 (prev: 0.3990)
# INFO :      Client 15793411968814662437: accuracy = 0.4010 (prev: 0.3460)
# INFO :      Client 2356968647547109814: accuracy = 0.3680 (prev: 0.3430)
# INFO :      Client 13308856144431293940: accuracy = 0.3920 (prev: 0.3580)
# INFO :      Round 3 aggregated accuracy: 0.4008
#
# INFO :
# INFO :      [ROUND 4]
# INFO :
# [ROUND 4]
# INFO :      Round 4: Initial selection - Selected clients ['13368760428531285841', '2356968647547109814', '15699243308435604940']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2635)          [repeated 2x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2634)          [repeated 4x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2635)          [repeated 10x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 2356968647547109814: accuracy = 0.4000 (prev: 0.3680)
# INFO :      Client 13308856144431293940: accuracy = 0.4030 (prev: 0.3920)
# INFO :      Client 482635144743528460: accuracy = 0.4090 (prev: 0.3850)
# INFO :      Client 5750641272721686063: accuracy = 0.4400 (prev: 0.4330)
# INFO :      Client 17279947229144345322: accuracy = 0.4260 (prev: 0.3980)
# INFO :      Client 15793411968814662437: accuracy = 0.4150 (prev: 0.4010)
# INFO :      Client 13368760428531285841: accuracy = 0.4440 (prev: 0.4110)
# INFO :      Client 13131094784264262786: accuracy = 0.4090 (prev: 0.3970)
# INFO :      Client 1807278659760480190: accuracy = 0.4470 (prev: 0.4440)
# INFO :      Client 15699243308435604940: accuracy = 0.4200 (prev: 0.3790)
# INFO :      Round 4 aggregated accuracy: 0.4213
#
# INFO :
# INFO :      [ROUND 5]
# INFO :
# [ROUND 5]
# INFO :      Round 5: Initial selection - Selected clients ['2356968647547109814', '13308856144431293940', '13131094784264262786']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2635)          [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2635)          [repeated 6x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=2635)          [repeated 12x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 13131094784264262786: accuracy = 0.4160 (prev: 0.4090)
# INFO :      Client 482635144743528460: accuracy = 0.4240 (prev: 0.4090)
# INFO :      Client 15699243308435604940: accuracy = 0.4210 (prev: 0.4200)
# INFO :      Client 1807278659760480190: accuracy = 0.4620 (prev: 0.4470)
# INFO :      Client 13368760428531285841: accuracy = 0.4570 (prev: 0.4440)
# INFO :      Client 5750641272721686063: accuracy = 0.4520 (prev: 0.4400)
# INFO :      Client 17279947229144345322: accuracy = 0.4400 (prev: 0.4260)
# INFO :      Client 13308856144431293940: accuracy = 0.4300 (prev: 0.4030)
# INFO :      Client 15793411968814662437: accuracy = 0.4430 (prev: 0.4150)
# INFO :      Client 2356968647547109814: accuracy = 0.4150 (prev: 0.4000)
# INFO :      Round 5 aggregated accuracy: 0.4360
#
# INFO :
# INFO :      [ROUND 6]
# INFO :
# [ROUND 6]
# INFO :      Round 6: Probabilistic selection - Selected clients ['2356968647547109814', '482635144743528460', '13368760428531285841']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2634)          [repeated 8x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2634)          [repeated 4x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=2635)          [repeated 12x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 17279947229144345322: accuracy = 0.4360 (prev: 0.4400)
# INFO :      Client 13368760428531285841: accuracy = 0.4670 (prev: 0.4570)
# INFO :      Client 13308856144431293940: accuracy = 0.4390 (prev: 0.4300)
# INFO :      Client 15699243308435604940: accuracy = 0.4270 (prev: 0.4210)
# INFO :      Client 482635144743528460: accuracy = 0.4550 (prev: 0.4240)
# INFO :      Client 5750641272721686063: accuracy = 0.4710 (prev: 0.4520)
# INFO :      Client 2356968647547109814: accuracy = 0.4300 (prev: 0.4150)
# INFO :      Client 13131094784264262786: accuracy = 0.4370 (prev: 0.4160)
# INFO :      Client 15793411968814662437: accuracy = 0.4500 (prev: 0.4430)
# INFO :      Client 1807278659760480190: accuracy = 0.4720 (prev: 0.4620)
# INFO :      Round 6 aggregated accuracy: 0.4484
#
# INFO :
# INFO :      [ROUND 7]
# INFO :
# [ROUND 7]
# INFO :      Round 7: Probabilistic selection - Selected clients ['15793411968814662437', '13131094784264262786', '1807278659760480190']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2634)          [repeated 8x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2634)          [repeated 2x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2635)             entirely in future versions of Flower.
# (ClientAppActor pid=2635)          [repeated 2x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2634)             entirely in future versions of Flower.
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 15699243308435604940: accuracy = 0.4430 (prev: 0.4270)
# INFO :      Client 13368760428531285841: accuracy = 0.4950 (prev: 0.4670)
# INFO :      Client 482635144743528460: accuracy = 0.4790 (prev: 0.4550)
# INFO :      Client 5750641272721686063: accuracy = 0.4820 (prev: 0.4710)
# INFO :      Client 15793411968814662437: accuracy = 0.4600 (prev: 0.4500)
# INFO :      Client 13131094784264262786: accuracy = 0.4640 (prev: 0.4370)
# INFO :      Client 2356968647547109814: accuracy = 0.4460 (prev: 0.4300)
# INFO :      Client 17279947229144345322: accuracy = 0.4580 (prev: 0.4360)
# INFO :      Client 1807278659760480190: accuracy = 0.4900 (prev: 0.4720)
# INFO :      Client 13308856144431293940: accuracy = 0.4380 (prev: 0.4390)
# INFO :      Round 7 aggregated accuracy: 0.4655
#
# INFO :
# INFO :      [ROUND 8]
# INFO :
# [ROUND 8]
# INFO :      Round 8: Probabilistic selection - Selected clients ['15699243308435604940', '17279947229144345322', '13368760428531285841']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=2635)          [repeated 4x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2634)          [repeated 4x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2634) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2635)          [repeated 10x across cluster]
# (ClientAppActor pid=2635) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2635)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2635)             entirely in future versions of Flower. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 5750641272721686063: accuracy = 0.4890 (prev: 0.4820)
# INFO :      Client 15699243308435604940: accuracy = 0.4620 (prev: 0.4430)
# INFO :      Client 15793411968814662437: accuracy = 0.4870 (prev: 0.4600)
# INFO :      Client 482635144743528460: accuracy = 0.4750 (prev: 0.4790)
# INFO :      Client 17279947229144345322: accuracy = 0.4570 (prev: 0.4580)
# INFO :      Client 2356968647547109814: accuracy = 0.4540 (prev: 0.4460)
# INFO :      Client 13308856144431293940: accuracy = 0.4530 (prev: 0.4380)
# INFO :      Client 13131094784264262786: accuracy = 0.4430 (prev: 0.4640)
# INFO :      Client 13368760428531285841: accuracy = 0.4970 (prev: 0.4950)
# INFO :      Client 1807278659760480190: accuracy = 0.4720 (prev: 0.4900)
# INFO :      Round 8 aggregated accuracy: 0.4689
#
# INFO :
# INFO :      [ROUND 9]
# INFO :
# [ROUND 9]
# INFO :      Round 9: Probabilistic selection - Selected clients ['1807278659760480190', '482635144743528460', '15699243308435604940']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=2635) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=2634)          [repeated 10x across cluster]
# (ClientAppActor pid=2634) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2634)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2634)             entirely in future versions of Flower. [repeated 5x across cluster]
# ...
# (ClientAppActor pid=11535) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=11535)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=11535)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=11535) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=11536)          [repeated 2x across cluster]
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11536)             entirely in future versions of Flower.
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11536)             entirely in future versions of Flower.
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=11535)          [repeated 4x across cluster]
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=11535)          [repeated 12x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 8435382644845326776: accuracy = 0.5780 (prev: 0.5720)
# INFO :      Client 5977108964263597260: accuracy = 0.5500 (prev: 0.5580)
# INFO :      Client 14188461170491901664: accuracy = 0.5980 (prev: 0.5890)
# INFO :      Client 16392783268410015504: accuracy = 0.5480 (prev: 0.5570)
# INFO :      Client 1776141291172909198: accuracy = 0.5630 (prev: 0.5750)
# INFO :      Client 18332287771768949470: accuracy = 0.5520 (prev: 0.5500)
# INFO :      Client 2303473192219204950: accuracy = 0.5480 (prev: 0.5420)
# INFO :      Client 17568481667652452028: accuracy = 0.5760 (prev: 0.5740)
# INFO :      Client 7046333295612275800: accuracy = 0.5540 (prev: 0.5500)
# INFO :      Client 753438858253950962: accuracy = 0.5840 (prev: 0.5950)
# INFO :      Round 18 aggregated accuracy: 0.5651
#
# INFO :
# INFO :      [ROUND 19]
# INFO :
# [ROUND 19]
# INFO :      Round 19: Probabilistic selection - Selected clients ['16392783268410015504', '753438858253950962', '8435382644845326776']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=11535)          [repeated 10x across cluster]
# (ClientAppActor pid=11535) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11535)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11535)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11536)             entirely in future versions of Flower.
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=11535)          [repeated 4x across cluster]
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=11535)          [repeated 10x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 17568481667652452028: accuracy = 0.5710 (prev: 0.5760)
# INFO :      Client 7046333295612275800: accuracy = 0.5450 (prev: 0.5540)
# INFO :      Client 1776141291172909198: accuracy = 0.5790 (prev: 0.5630)
# INFO :      Client 753438858253950962: accuracy = 0.5810 (prev: 0.5840)
# INFO :      Client 8435382644845326776: accuracy = 0.5780 (prev: 0.5780)
# INFO :      Client 5977108964263597260: accuracy = 0.5390 (prev: 0.5500)
# INFO :      Client 18332287771768949470: accuracy = 0.5530 (prev: 0.5520)
# INFO :      Client 14188461170491901664: accuracy = 0.6090 (prev: 0.5980)
# INFO :      Client 16392783268410015504: accuracy = 0.5690 (prev: 0.5480)
# INFO :      Client 2303473192219204950: accuracy = 0.5620 (prev: 0.5480)
# INFO :      Round 19 aggregated accuracy: 0.5686
#
# INFO :
# INFO :      [ROUND 20]
# INFO :
# [ROUND 20]
# INFO :      Round 20: Probabilistic selection - Selected clients ['18332287771768949470', '1776141291172909198', '8435382644845326776']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=11535)          [repeated 10x across cluster]
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=11536)          [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11536)             entirely in future versions of Flower.
# (ClientAppActor pid=11535) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11535)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11535)             entirely in future versions of Flower.
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=11535)          [repeated 4x across cluster]
# (ClientAppActor pid=11535) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=11535) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=11535)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=11535)             entirely in future versions of Flower.
# (ClientAppActor pid=11536) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=11536)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=11536)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=11536)          [repeated 10x across cluster]
# (ClientAppActor pid=11536) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 14188461170491901664: accuracy = 0.6060 (prev: 0.6090)
# INFO :      Client 7046333295612275800: accuracy = 0.5560 (prev: 0.5450)
# INFO :      Client 16392783268410015504: accuracy = 0.5800 (prev: 0.5690)
# INFO :      Client 753438858253950962: accuracy = 0.5890 (prev: 0.5810)
# INFO :      Client 1776141291172909198: accuracy = 0.5880 (prev: 0.5790)
# INFO :      Client 18332287771768949470: accuracy = 0.5560 (prev: 0.5530)
# INFO :      Client 17568481667652452028: accuracy = 0.5740 (prev: 0.5710)
# INFO :      Client 5977108964263597260: accuracy = 0.5510 (prev: 0.5390)
# INFO :      Client 8435382644845326776: accuracy = 0.5950 (prev: 0.5780)
# INFO :      Client 2303473192219204950: accuracy = 0.5640 (prev: 0.5620)
# INFO :      Round 20 aggregated accuracy: 0.5759
#
# INFO :      [SUMMARY]
# Total communication rounds: 60
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 448.49s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06295582950115204
# INFO :      		round 2: 0.05580676001310349
# INFO :      		round 3: 0.05305246057510376
# INFO :      		round 4: 0.05031347153186798
# INFO :      		round 5: 0.048687011969089505
# INFO :      		round 6: 0.04755766975283623
# INFO :      		round 7: 0.04593525452017784
# INFO :      		round 8: 0.04534842621088028
# INFO :      		round 9: 0.04424402778148651
# INFO :      		round 10: 0.043445482021570205
# INFO :      		round 11: 0.04313784299492836
# INFO :      		round 12: 0.042409834372997286
# INFO :      		round 13: 0.041481528651714325
# INFO :      		round 14: 0.040945534396171566
# INFO :      		round 15: 0.0402311146736145
# INFO :      		round 16: 0.03989264454841614
# INFO :      		round 17: 0.03930565639734268
# INFO :      		round 18: 0.03924107767939568
# INFO :      		round 19: 0.03879690689444542
# INFO :      		round 20: 0.038549965381622316
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.2919),
# INFO :      	              (2, 0.3551),
# INFO :      	              (3, 0.3981),
# INFO :      	              (4, 0.4284),
# INFO :      	              (5, 0.4423),
# INFO :      	              (6, 0.4641),
# INFO :      	              (7, 0.4759),
# INFO :      	              (8, 0.4854),
# INFO :      	              (9, 0.5025),
# INFO :      	              (10, 0.5036),
# INFO :      	              (11, 0.521),
# INFO :      	              (12, 0.5198),
# INFO :      	              (13, 0.5386),
# INFO :      	              (14, 0.5374),
# INFO :      	              (15, 0.5528),
# INFO :      	              (16, 0.5564),
# INFO :      	              (17, 0.5662),
# INFO :      	              (18, 0.5651),
# INFO :      	              (19, 0.5686),
# INFO :      	              (20, 0.5759)]}
# INFO :

# %%
# Start simulation
if __name__ == "__main__":
    # Set desired k and alpha values
    K = 3
    ALPHA = 0.5  # Change alpha value as needed

    print(f"\nStarting simulation with k = {K} and alpha = {ALPHA}\n{'='*50}")

    # Create strategy instance
    strategy_strategy_final = CS_final(
        fraction_fit=1.0,
        fraction_evaluate=1.0,
        min_fit_clients=2,
        min_evaluate_clients=2,
        min_available_clients=2,
        initial_rounds=INITIAL_ROUNDS,
        k=K,
        alpha=ALPHA,
        total_rounds=20,
    )

    # Start the simulation
    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=NUM_ROUNDS),
        strategy=strategy_strategy_final,
    )
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# Starting simulation with k = 3 and alpha = 0.5
# ==================================================
# 2024-12-05 17:09:42,887	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 2.0, 'object_store_memory': 3992028364.0, 'memory': 7984056731.0, 'node:__internal_head__': 1.0, 'node:172.28.0.12': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=1818) 2024-12-05 17:09:49.276976: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=1818) 2024-12-05 17:09:49.320655: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=1818) 2024-12-05 17:09:49.332959: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=1818) 2024-12-05 17:09:51.972618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=1820) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=1820) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=1820) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=1820) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=1820) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=1820)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (pid=1820) 2024-12-05 17:09:49.295978: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=1820) 2024-12-05 17:09:49.338200: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=1820) 2024-12-05 17:09:49.349897: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=1820) 2024-12-05 17:09:52.022469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating train split:  16%|█▋        | 8200/50000 [00:00<00:00, 81017.85 examples/s]
# Generating train split:  33%|███▎      | 16700/50000 [00:00<00:00, 83007.33 examples/s]
# Generating train split:  52%|█████▏    | 26000/50000 [00:00<00:00, 87089.68 examples/s]
# Generating train split:  73%|███████▎  | 36400/50000 [00:00<00:00, 93437.55 examples/s]
# Generating train split:  99%|█████████▉| 49500/50000 [00:00<00:00, 89380.56 examples/s]
# Generating train split: 100%|██████████| 50000/50000 [00:00<00:00, 88284.67 examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating test split:  76%|███████▌  | 7600/10000 [00:00<00:00, 74289.27 examples/s]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :
# [ROUND 1]
# INFO :      Round 1: Initial selection - Selected clients ['4605770795790349976', '10831623807110553698', '14170468466287639773']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 76029.77 examples/s]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)
# (ClientAppActor pid=1818) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=1818) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=1818) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=1818) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=1818) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=1818)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=1818)          [repeated 4x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)          [repeated 10x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 14157798991649501988: accuracy = 0.2840 (prev: 0.0000)
# INFO :      Client 5950156626930322270: accuracy = 0.2990 (prev: 0.0000)
# INFO :      Client 933620172704003771: accuracy = 0.2630 (prev: 0.0000)
# INFO :      Client 7174710563147246794: accuracy = 0.2740 (prev: 0.0000)
# INFO :      Client 11493441919573469849: accuracy = 0.2910 (prev: 0.0000)
# INFO :      Client 10831623807110553698: accuracy = 0.2750 (prev: 0.0000)
# INFO :      Client 13084076233488400636: accuracy = 0.2600 (prev: 0.0000)
# INFO :      Client 14170468466287639773: accuracy = 0.3000 (prev: 0.0000)
# INFO :      Client 16299095536753626459: accuracy = 0.2870 (prev: 0.0000)
# INFO :      Client 4605770795790349976: accuracy = 0.3290 (prev: 0.0000)
# INFO :      Round 1 aggregated accuracy: 0.2862
#
# INFO :
# INFO :      [ROUND 2]
# INFO :
# [ROUND 2]
# INFO :      Round 2: Initial selection - Selected clients ['13084076233488400636', '933620172704003771', '7174710563147246794']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)          [repeated 10x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=1818)          [repeated 4x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)          [repeated 10x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 10831623807110553698: accuracy = 0.3420 (prev: 0.2750)
# INFO :      Client 14170468466287639773: accuracy = 0.3840 (prev: 0.3000)
# INFO :      Client 7174710563147246794: accuracy = 0.3380 (prev: 0.2740)
# INFO :      Client 5950156626930322270: accuracy = 0.3660 (prev: 0.2990)
# INFO :      Client 13084076233488400636: accuracy = 0.3520 (prev: 0.2600)
# INFO :      Client 16299095536753626459: accuracy = 0.3610 (prev: 0.2870)
# INFO :      Client 4605770795790349976: accuracy = 0.4040 (prev: 0.3290)
# INFO :      Client 933620172704003771: accuracy = 0.3470 (prev: 0.2630)
# INFO :      Client 11493441919573469849: accuracy = 0.3500 (prev: 0.2910)
# INFO :      Client 14157798991649501988: accuracy = 0.3310 (prev: 0.2840)
# INFO :      Round 2 aggregated accuracy: 0.3575
#
# INFO :
# INFO :      [ROUND 3]
# INFO :
# [ROUND 3]
# INFO :      Round 3: Initial selection - Selected clients ['14157798991649501988', '11493441919573469849', '16299095536753626459']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)          [repeated 2x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1818)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 11493441919573469849: accuracy = 0.3970 (prev: 0.3500)
# INFO :      Client 14157798991649501988: accuracy = 0.3630 (prev: 0.3310)
# INFO :      Client 7174710563147246794: accuracy = 0.3640 (prev: 0.3380)
# INFO :      Client 10831623807110553698: accuracy = 0.3610 (prev: 0.3420)
# INFO :      Client 16299095536753626459: accuracy = 0.3770 (prev: 0.3610)
# INFO :      Client 5950156626930322270: accuracy = 0.4050 (prev: 0.3660)
# INFO :      Client 933620172704003771: accuracy = 0.3710 (prev: 0.3470)
# INFO :      Client 13084076233488400636: accuracy = 0.3830 (prev: 0.3520)
# INFO :      Client 14170468466287639773: accuracy = 0.4000 (prev: 0.3840)
# INFO :      Client 4605770795790349976: accuracy = 0.4160 (prev: 0.4040)
# INFO :      Round 3 aggregated accuracy: 0.3837
#
# INFO :
# INFO :      [ROUND 4]
# INFO :
# [ROUND 4]
# INFO :      Round 4: Initial selection - Selected clients ['5950156626930322270', '10831623807110553698', '14157798991649501988']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 5950156626930322270: accuracy = 0.4200 (prev: 0.4050)
# INFO :      Client 14170468466287639773: accuracy = 0.4390 (prev: 0.4000)
# INFO :      Client 4605770795790349976: accuracy = 0.4360 (prev: 0.4160)
# INFO :      Client 16299095536753626459: accuracy = 0.4130 (prev: 0.3770)
# INFO :      Client 14157798991649501988: accuracy = 0.3930 (prev: 0.3630)
# INFO :      Client 933620172704003771: accuracy = 0.3910 (prev: 0.3710)
# INFO :      Client 13084076233488400636: accuracy = 0.4040 (prev: 0.3830)
# INFO :      Client 7174710563147246794: accuracy = 0.3940 (prev: 0.3640)
# INFO :      Client 11493441919573469849: accuracy = 0.4120 (prev: 0.3970)
# INFO :      Client 10831623807110553698: accuracy = 0.3880 (prev: 0.3610)
# INFO :      Round 4 aggregated accuracy: 0.4090
#
# INFO :
# INFO :      [ROUND 5]
# INFO :
# [ROUND 5]
# INFO :      Round 5: Initial selection - Selected clients ['10831623807110553698', '933620172704003771', '14157798991649501988']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 13084076233488400636: accuracy = 0.4160 (prev: 0.4040)
# INFO :      Client 7174710563147246794: accuracy = 0.4040 (prev: 0.3940)
# INFO :      Client 4605770795790349976: accuracy = 0.4700 (prev: 0.4360)
# INFO :      Client 11493441919573469849: accuracy = 0.4520 (prev: 0.4120)
# INFO :      Client 5950156626930322270: accuracy = 0.4470 (prev: 0.4200)
# INFO :      Client 10831623807110553698: accuracy = 0.4240 (prev: 0.3880)
# INFO :      Client 16299095536753626459: accuracy = 0.4190 (prev: 0.4130)
# INFO :      Client 14170468466287639773: accuracy = 0.4510 (prev: 0.4390)
# INFO :      Client 933620172704003771: accuracy = 0.4220 (prev: 0.3910)
# INFO :      Client 14157798991649501988: accuracy = 0.4140 (prev: 0.3930)
# INFO :      Round 5 aggregated accuracy: 0.4319
#
# INFO :
# INFO :      [ROUND 6]
# INFO :
# [ROUND 6]
# INFO :      Round 6: Probabilistic selection - Selected clients ['7174710563147246794', '13084076233488400636', '5950156626930322270']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=1818)          [repeated 10x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 16299095536753626459: accuracy = 0.4360 (prev: 0.4190)
# INFO :      Client 11493441919573469849: accuracy = 0.4610 (prev: 0.4520)
# INFO :      Client 14170468466287639773: accuracy = 0.4660 (prev: 0.4510)
# INFO :      Client 14157798991649501988: accuracy = 0.4310 (prev: 0.4140)
# INFO :      Client 13084076233488400636: accuracy = 0.4170 (prev: 0.4160)
# INFO :      Client 5950156626930322270: accuracy = 0.4670 (prev: 0.4470)
# INFO :      Client 10831623807110553698: accuracy = 0.4370 (prev: 0.4240)
# INFO :      Client 7174710563147246794: accuracy = 0.4200 (prev: 0.4040)
# INFO :      Client 4605770795790349976: accuracy = 0.4630 (prev: 0.4700)
# INFO :      Client 933620172704003771: accuracy = 0.4280 (prev: 0.4220)
# INFO :      Round 6 aggregated accuracy: 0.4426
#
# INFO :
# INFO :      [ROUND 7]
# INFO :
# [ROUND 7]
# INFO :      Round 7: Probabilistic selection - Selected clients ['14157798991649501988', '10831623807110553698', '4605770795790349976']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 10831623807110553698: accuracy = 0.4320 (prev: 0.4370)
# INFO :      Client 933620172704003771: accuracy = 0.4350 (prev: 0.4280)
# INFO :      Client 16299095536753626459: accuracy = 0.4410 (prev: 0.4360)
# INFO :      Client 5950156626930322270: accuracy = 0.4680 (prev: 0.4670)
# INFO :      Client 11493441919573469849: accuracy = 0.4720 (prev: 0.4610)
# INFO :      Client 7174710563147246794: accuracy = 0.4290 (prev: 0.4200)
# INFO :      Client 14157798991649501988: accuracy = 0.4520 (prev: 0.4310)
# INFO :      Client 14170468466287639773: accuracy = 0.4810 (prev: 0.4660)
# INFO :      Client 13084076233488400636: accuracy = 0.4320 (prev: 0.4170)
# INFO :      Client 4605770795790349976: accuracy = 0.4640 (prev: 0.4630)
# INFO :      Round 7 aggregated accuracy: 0.4506
#
# INFO :
# INFO :      [ROUND 8]
# INFO :
# [ROUND 8]
# INFO :      Round 8: Probabilistic selection - Selected clients ['933620172704003771', '11493441919573469849', '5950156626930322270']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1818)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 16299095536753626459: accuracy = 0.4530 (prev: 0.4410)
# INFO :      Client 5950156626930322270: accuracy = 0.4770 (prev: 0.4680)
# INFO :      Client 7174710563147246794: accuracy = 0.4410 (prev: 0.4290)
# INFO :      Client 13084076233488400636: accuracy = 0.4510 (prev: 0.4320)
# INFO :      Client 933620172704003771: accuracy = 0.4660 (prev: 0.4350)
# INFO :      Client 14157798991649501988: accuracy = 0.4700 (prev: 0.4520)
# INFO :      Client 4605770795790349976: accuracy = 0.4820 (prev: 0.4640)
# INFO :      Client 14170468466287639773: accuracy = 0.4990 (prev: 0.4810)
# INFO :      Client 11493441919573469849: accuracy = 0.4740 (prev: 0.4720)
# INFO :      Client 10831623807110553698: accuracy = 0.4580 (prev: 0.4320)
# INFO :      Round 8 aggregated accuracy: 0.4671
#
# INFO :
# INFO :      [ROUND 9]
# INFO :
# [ROUND 9]
# INFO :      Round 9: Probabilistic selection - Selected clients ['4605770795790349976', '13084076233488400636', '933620172704003771']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 8x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 2x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 6x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 14170468466287639773: accuracy = 0.5010 (prev: 0.4990)
# INFO :      Client 11493441919573469849: accuracy = 0.4880 (prev: 0.4740)
# INFO :      Client 7174710563147246794: accuracy = 0.4550 (prev: 0.4410)
# INFO :      Client 10831623807110553698: accuracy = 0.4780 (prev: 0.4580)
# INFO :      Client 16299095536753626459: accuracy = 0.4590 (prev: 0.4530)
# INFO :      Client 4605770795790349976: accuracy = 0.5100 (prev: 0.4820)
# INFO :      Client 933620172704003771: accuracy = 0.4770 (prev: 0.4660)
# INFO :      Client 14157798991649501988: accuracy = 0.4650 (prev: 0.4700)
# INFO :      Client 5950156626930322270: accuracy = 0.4920 (prev: 0.4770)
# INFO :      Client 13084076233488400636: accuracy = 0.4510 (prev: 0.4510)
# INFO :      Round 9 aggregated accuracy: 0.4776
#
# INFO :
# INFO :      [ROUND 10]
# INFO :
# [ROUND 10]
# INFO :      Round 10: Probabilistic selection - Selected clients ['14170468466287639773', '10831623807110553698', '16299095536753626459']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1820)          [repeated 8x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# ...
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 6x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 6x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 6x across cluster]
# (ClientAppActor pid=1818)          [repeated 12x across cluster]
# (ClientAppActor pid=1818) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 11493441919573469849: accuracy = 0.5380 (prev: 0.5360)
# INFO :      Client 14170468466287639773: accuracy = 0.5580 (prev: 0.5640)
# INFO :      Client 7174710563147246794: accuracy = 0.5220 (prev: 0.5070)
# INFO :      Client 14157798991649501988: accuracy = 0.5320 (prev: 0.5270)
# INFO :      Client 933620172704003771: accuracy = 0.5460 (prev: 0.5430)
# INFO :      Client 4605770795790349976: accuracy = 0.5740 (prev: 0.5800)
# INFO :      Client 16299095536753626459: accuracy = 0.5170 (prev: 0.5170)
# INFO :      Client 13084076233488400636: accuracy = 0.5070 (prev: 0.5090)
# INFO :      Client 10831623807110553698: accuracy = 0.5420 (prev: 0.5190)
# INFO :      Client 5950156626930322270: accuracy = 0.5650 (prev: 0.5540)
# INFO :      Round 18 aggregated accuracy: 0.5401
#
# INFO :
# INFO :      [ROUND 19]
# INFO :
# [ROUND 19]
# INFO :      Round 19: Probabilistic selection - Selected clients ['13084076233488400636', '14170468466287639773', '11493441919573469849']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820)          [repeated 10x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=1820)          [repeated 4x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=1818)          [repeated 10x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 14170468466287639773: accuracy = 0.5620 (prev: 0.5580)
# INFO :      Client 14157798991649501988: accuracy = 0.5260 (prev: 0.5320)
# INFO :      Client 5950156626930322270: accuracy = 0.5680 (prev: 0.5650)
# INFO :      Client 10831623807110553698: accuracy = 0.5320 (prev: 0.5420)
# INFO :      Client 16299095536753626459: accuracy = 0.5240 (prev: 0.5170)
# INFO :      Client 11493441919573469849: accuracy = 0.5230 (prev: 0.5380)
# INFO :      Client 7174710563147246794: accuracy = 0.5270 (prev: 0.5220)
# INFO :      Client 13084076233488400636: accuracy = 0.5110 (prev: 0.5070)
# INFO :      Client 4605770795790349976: accuracy = 0.5750 (prev: 0.5740)
# INFO :      Client 933620172704003771: accuracy = 0.5430 (prev: 0.5460)
# INFO :      Round 19 aggregated accuracy: 0.5391
#
# INFO :
# INFO :      [ROUND 20]
# INFO :
# [ROUND 20]
# INFO :      Round 20: Probabilistic selection - Selected clients ['7174710563147246794', '14157798991649501988', '10831623807110553698']
# INFO :      configure_fit: strategy sampled 3 clients (out of 10)
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=1818)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 3 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1818)          [repeated 2x across cluster]
# (ClientAppActor pid=1818) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1818)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1818)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=1820)             entirely in future versions of Flower.
# (ClientAppActor pid=1820)          [repeated 12x across cluster]
# (ClientAppActor pid=1820) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=1820)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=1820)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=1820) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 6x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 933620172704003771: accuracy = 0.5520 (prev: 0.5430)
# INFO :      Client 5950156626930322270: accuracy = 0.5720 (prev: 0.5680)
# INFO :      Client 14157798991649501988: accuracy = 0.5410 (prev: 0.5260)
# INFO :      Client 14170468466287639773: accuracy = 0.5750 (prev: 0.5620)
# INFO :      Client 11493441919573469849: accuracy = 0.5390 (prev: 0.5230)
# INFO :      Client 7174710563147246794: accuracy = 0.5530 (prev: 0.5270)
# INFO :      Client 10831623807110553698: accuracy = 0.5500 (prev: 0.5320)
# INFO :      Client 16299095536753626459: accuracy = 0.5290 (prev: 0.5240)
# INFO :      Client 4605770795790349976: accuracy = 0.5780 (prev: 0.5750)
# INFO :      Client 13084076233488400636: accuracy = 0.5310 (prev: 0.5110)
# INFO :      Round 20 aggregated accuracy: 0.5520
#
# INFO :      [SUMMARY]
# Total communication rounds: 60
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 438.27s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06322498421669007
# INFO :      		round 2: 0.05699414191246033
# INFO :      		round 3: 0.053914040231704714
# INFO :      		round 4: 0.052153799164295196
# INFO :      		round 5: 0.04983584887981415
# INFO :      		round 6: 0.048798950123786926
# INFO :      		round 7: 0.048098600912094114
# INFO :      		round 8: 0.04657601997256279
# INFO :      		round 9: 0.04570794046521187
# INFO :      		round 10: 0.044656706649065014
# INFO :      		round 11: 0.044468335896730424
# INFO :      		round 12: 0.0434598198056221
# INFO :      		round 13: 0.04320961042046547
# INFO :      		round 14: 0.042276133847236635
# INFO :      		round 15: 0.042457448559999465
# INFO :      		round 16: 0.042281415843963624
# INFO :      		round 17: 0.04106640675663948
# INFO :      		round 18: 0.041088466656208036
# INFO :      		round 19: 0.04084958875775337
# INFO :      		round 20: 0.03989353541135788
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.2862),
# INFO :      	              (2, 0.3575),
# INFO :      	              (3, 0.3837),
# INFO :      	              (4, 0.409),
# INFO :      	              (5, 0.4319),
# INFO :      	              (6, 0.4426),
# INFO :      	              (7, 0.4506),
# INFO :      	              (8, 0.4671),
# INFO :      	              (9, 0.4776),
# INFO :      	              (10, 0.4939),
# INFO :      	              (11, 0.4883),
# INFO :      	              (12, 0.5096),
# INFO :      	              (13, 0.5085),
# INFO :      	              (14, 0.5246),
# INFO :      	              (15, 0.5223),
# INFO :      	              (16, 0.5252),
# INFO :      	              (17, 0.5356),
# INFO :      	              (18, 0.5401),
# INFO :      	              (19, 0.5391),
# INFO :      	              (20, 0.552)]}
# INFO :

# %% [markdown]
# # **Visualisation**
# For comparing accuracy over communication round for variations of K and Alpha values.

# %%
import itertools
import csv
import flwr as fl
from flwr.server.client_manager import ClientManager
from flwr.server.client_proxy import ClientProxy
from flwr.server.strategy import Strategy
from flwr.common import (
    EvaluateIns,
    EvaluateRes,
    FitIns,
    FitRes,
    Parameters,
    Scalar,
    ndarrays_to_parameters,
    parameters_to_ndarrays,
)
from typing import Dict, List, Optional, Tuple
import numpy as np
from flwr.common.logger import log
from logging import INFO, WARNING, ERROR
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Define variables
NUM_CLIENTS = 10
INITIAL_ROUNDS = 5
NUM_ROUNDS = 20

class CS_final(Strategy):
    def __init__(
        self,
        fraction_fit: float = 1.0,
        fraction_evaluate: float = 1.0,
        min_fit_clients: int = 2,
        min_evaluate_clients: int = 2,
        min_available_clients: int = 2,
        evaluate_fn=None,
        on_fit_config_fn=None,
        on_evaluate_config_fn=None,
        accept_failures: bool = True,
        initial_rounds: int = 5,  # Minimum number of initial rounds
        k: int = 3,               # Number of clients to select per round
        alpha: float = 0.5,       # Smoothing factor for selection probability
        total_rounds: int = 20,   # Total number of rounds
    ):
        super().__init__()
        self.fraction_fit = fraction_fit
        self.fraction_evaluate = fraction_evaluate
        self.min_fit_clients = min_fit_clients
        self.min_evaluate_clients = min_evaluate_clients
        self.min_available_clients = min_available_clients
        self.evaluate_fn = evaluate_fn
        self.on_fit_config_fn = on_fit_config_fn
        self.on_evaluate_config_fn = on_evaluate_config_fn
        self.accept_failures = accept_failures

        self.initial_rounds = initial_rounds
        self.k = k
        self.alpha = alpha
        self.client_accuracies: Dict[str, float] = {}
        self.current_round = 0
        self.parameters: Optional[Parameters] = None  # Will be set after initialization
        self.global_accuracy: float = 0.0  # Store global model accuracy

        self.total_rounds = total_rounds
        self.total_communications = 0

        # Track clients selected in initial rounds to ensure all participate at least once
        self.initial_selected_clients: set = set()

    def initialize_parameters(
        self, client_manager: ClientManager
    ) -> Optional[Parameters]:
        """Initialize global model parameters."""
        # Return None to let the server initialize parameters from a client
        return None

    def configure_fit(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, FitIns]]:
        """Configure the next round of training."""
        self.current_round = server_round
        log(INFO, f"\n[ROUND {server_round}]")

        clients_dict = client_manager.all()
        available_cids = list(clients_dict.keys())

        # Ensure all clients have an accuracy value
        for cid in available_cids:
            if cid not in self.client_accuracies:
                self.client_accuracies[cid] = 0.0  # Default accuracy

        selected_cids = []

        if server_round <= self.initial_rounds:
            # Select top-k least accurate clients that haven't been selected yet
            # Sort clients by least accuracy
            sorted_clients = sorted(
                self.client_accuracies.items(), key=lambda x: x[1]
            )
            # Select clients not yet selected
            available_for_selection = [
                cid for cid, _ in sorted_clients if cid not in self.initial_selected_clients
            ]
            # Select up to k clients
            for cid, _ in sorted_clients:
                if cid not in self.initial_selected_clients:
                    selected_cids.append(cid)
                    self.initial_selected_clients.add(cid)
                    if len(selected_cids) == self.k:
                        break
            # If not enough unique clients, fill the rest with top-k least accurate
            if len(selected_cids) < self.k:
                additional = self.k - len(selected_cids)
                for cid, _ in sorted_clients:
                    if cid not in selected_cids:
                        selected_cids.append(cid)
                        if len(selected_cids) == self.k:
                            break
            log(
                INFO,
                f"Round {server_round}: Initial selection - Selected clients {selected_cids}",
            )
        else:
            # Probabilistic selection based on 1 - alpha * accuracy
            probabilities = {}
            for cid in available_cids:
                accuracy = self.client_accuracies[cid]
                prob = max(1 - self.alpha * accuracy, 0.0)
                probabilities[cid] = prob

            # Normalize probabilities
            total_prob = sum(probabilities.values())
            if total_prob == 0:
                # If total_prob is zero, default to uniform probabilities
                for cid in probabilities:
                    probabilities[cid] = 1.0 / len(probabilities)
            else:
                for cid in probabilities:
                    probabilities[cid] /= total_prob

            # Select k unique clients based on probabilities
            selected_cids = list(
                np.random.choice(
                    available_cids,
                    size=self.k,
                    replace=False,
                    p=[probabilities[cid] for cid in available_cids],
                )
            )
            log(
                INFO,
                f"Round {server_round}: Probabilistic selection - Selected clients {selected_cids}",
            )

        # Update total communications
        self.total_communications += len(selected_cids)

        clients = [
            clients_dict.get(cid) for cid in selected_cids if clients_dict.get(cid) is not None
        ]

        # Create fit instructions
        config = self.on_fit_config_fn(server_round) if self.on_fit_config_fn else {}
        fit_ins = FitIns(parameters, config)

        # Return client configurations as a list of (ClientProxy, FitIns)
        return [(client, fit_ins) for client in clients if client is not None]

    def configure_evaluate(
        self,
        server_round: int,
        parameters: Parameters,
        client_manager: ClientManager,
    ) -> List[Tuple[ClientProxy, EvaluateIns]]:
        """Configure the next round of evaluation."""
        # Evaluate on all clients
        clients = list(client_manager.all().values())

        # Create evaluate instructions
        config = (
            self.on_evaluate_config_fn(server_round)
            if self.on_evaluate_config_fn
            else {}
        )
        evaluate_ins = EvaluateIns(parameters, config)

        # Return client configurations as a list of (ClientProxy, EvaluateIns)
        return [(client, evaluate_ins) for client in clients if client is not None]

    def aggregate_fit(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, FitRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[Parameters], Dict[str, Scalar]]:
        """Aggregate fit results using weighted average."""
        if not results:
            return None, {}


        total_examples = sum([res.num_examples for _, res in results])

        # Initialize the list to store weighted updates
        weighted_updates = []

        for _, fit_res in results:
            # Deserialize parameters to ndarrays
            client_weights = parameters_to_ndarrays(fit_res.parameters)
            # Calculate the weight based on the number of examples
            num_examples = fit_res.num_examples
            weight = num_examples / total_examples
            # Append the weighted client weights
            weighted_updates.append([layer * weight for layer in client_weights])

        # Sum the weighted updates
        aggregated_weights = [
            np.sum([update[layer] for update in weighted_updates], axis=0)
            for layer in range(len(weighted_updates[0]))
        ]

        # Serialize aggregated weights back to Parameters
        aggregated_parameters = ndarrays_to_parameters(aggregated_weights)

        # Return aggregated parameters and an empty metrics dictionary
        return aggregated_parameters, {}

    def aggregate_evaluate(
        self,
        server_round: int,
        results: List[Tuple[ClientProxy, EvaluateRes]],
        failures: List[BaseException],
    ) -> Tuple[Optional[float], Dict[str, Scalar]]:
        """Aggregate evaluation results."""
        if not results:
            return None, {}

        # Compute weighted loss
        losses = [res.num_examples * res.loss for _, res in results]
        examples = [res.num_examples for _, res in results]
        aggregated_loss = sum(losses) / sum(examples)

        # Compute weighted accuracy
        accuracies = [
            res.num_examples * res.metrics.get("accuracy", 0.0)
            for _, res in results
        ]
        aggregated_accuracy = sum(accuracies) / sum(examples)
        self.global_accuracy = aggregated_accuracy  # Store global accuracy

        # Update client accuracies
        for client_proxy, eval_res in results:
            cid = client_proxy.cid  # Correctly retrieve the client ID
            accuracy = eval_res.metrics.get("accuracy", 0.0)
            prev_accuracy = self.client_accuracies.get(cid, 0.0)
            self.client_accuracies[cid] = accuracy

            # Log client accuracies
            log(
                INFO,
                f"Client {cid}: accuracy = {accuracy:.4f} (prev: {prev_accuracy:.4f})",
            )

        # Log aggregated accuracy
        log(
            INFO,
            f"Round {server_round} aggregated accuracy: {aggregated_accuracy:.4f}\n",
        )

        # Print total communications after the last round
        if server_round == self.total_rounds:
            log(
                INFO,
                f"[SUMMARY]\nTotal communication rounds: {self.total_communications}",
            )

        # Return aggregated loss and metrics
        return aggregated_loss, {"accuracy": aggregated_accuracy}

    def evaluate(
        self,
        server_round: int,
        parameters: Parameters,
    ) -> Optional[Tuple[float, Dict[str, Scalar]]]:
        """Evaluate model parameters using an optional validation function."""
        if self.evaluate_fn is None:
            # No validation function provided
            return None
        return self.evaluate_fn(server_round, parameters)

# %%
def run_simulation(k: int, alpha: float, initial_rounds: int, total_rounds: int) -> Dict:
    """
    Runs a single federated learning simulation with given k and alpha.

    Args:
        k (int): Number of clients to select per round.
        alpha (float): Smoothing factor for selection probability.
        initial_rounds (int): Number of initial rounds to enforce top-k selection.
        total_rounds (int): Total number of communication rounds.

    Returns:
        Dict: A dictionary containing k, alpha, final_accuracy, and total_communications.
    """
    print(f"\nRunning simulation with k={k}, alpha={alpha}")

    # Initialize the strategy with current k and alpha
    strategy = CS_final(
        fraction_fit=1.0,
        fraction_evaluate=1.0,
        min_fit_clients=2,
        min_evaluate_clients=2,
        min_available_clients=2,
        initial_rounds=initial_rounds,
        k=k,
        alpha=alpha,
        total_rounds=total_rounds,
    )

    # Start the Flower simulation
    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=NUM_CLIENTS,
        config=fl.server.ServerConfig(num_rounds=total_rounds),
        strategy=strategy,
    )

    # After simulation, get the metrics
    final_accuracy = strategy.global_accuracy
    total_communications = strategy.total_communications

    print(f"Completed simulation with k={k}, alpha={alpha}: Accuracy={final_accuracy}, Communications={total_communications}")

    return {
        'k': k,
        'alpha': alpha,
        'final_accuracy': final_accuracy,
        'total_communications': total_communications
    }

# %% [markdown]
# Plot the graph

# %%
import plotly.express as px
import plotly.graph_objects as go

def main():
    # Define the range of k and alpha values
    #k_values = [2, 3, 5, 7]
    #alpha_values = [0.1, 0.2, 0.5, 0.8]

    k_values = [2, 3, 5, 7]
    alpha_values = [0.1, 0.2, 0.5, 0.8]

    # Initialize a list to store experiment results
    experiment_results = []

    # Iterate over all combinations of k and alpha
    for k, alpha in itertools.product(k_values, alpha_values):
        result = run_simulation(
            k=k,
            alpha=alpha,
            initial_rounds=INITIAL_ROUNDS,
            total_rounds=NUM_ROUNDS
        )
        experiment_results.append(result)

    # Save the results to a experiment_results.csv file
    csv_file = 'experiment_results.csv'
    df = pd.DataFrame(experiment_results)
    df.to_csv(csv_file, index=False)
    print(f"\nAll experiments completed. Results saved to {csv_file}")

    # visualization
    visualize_results(df)

def visualize_results(df: pd.DataFrame):


    # Create a combined label for legend entries
    df['params'] = df.apply(lambda row: f"k={row['k']}, alpha={row['alpha']}", axis=1)

    # scatter plot
    fig = px.scatter(
        df,
        x='final_accuracy',
        y='total_communications',
        color='params',
        hover_data={
            'k': True,
            'alpha': True,
            'final_accuracy': ':.4f',
            'total_communications': True
        },
        labels={
            'final_accuracy': 'Final Accuracy',
            'total_communications': 'Total Communication Rounds',
            'params': 'Parameters'
        },
        title='Federated Learning Performance: Accuracy vs Communication Rounds'
    )


    fig.update_traces(
        marker=dict(
            size=12,
            opacity=0.8,
            line=dict(width=1, color='DarkSlateGrey')
        )
    )


    fig.update_layout(
        legend_title_text='Parameters',
        xaxis_title='Final Accuracy',
        yaxis_title='Total Communication Rounds',
        hovermode='closest',
        margin=dict(l=60, r=200, t=60, b=60),
        legend=dict(
            x=1.05,
            y=1,
            xanchor='left',
            yanchor='top',
            bgcolor='rgba(255,255,255,0.9)',
            bordercolor='rgba(0,0,0,0.1)',
            borderwidth=1
        )
    )

    # Save to HTML and show
    fig.write_html('interactive_plot.html')
    fig.show()


if __name__ == "__main__":
    main()
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# WARNING:flwr:DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=20, no round_timeout
# Running simulation with k=2, alpha=0.1
# 2024-12-12 12:59:39,138	INFO worker.py:1752 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 2.0, 'object_store_memory': 4010010624.0, 'memory': 8020021248.0, 'node:172.28.0.12': 1.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 2 actors
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# (pid=2295) 2024-12-12 12:59:43.508650: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2295) 2024-12-12 12:59:43.557216: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2295) 2024-12-12 12:59:43.568913: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2295) 2024-12-12 12:59:45.757959: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# (ClientAppActor pid=2296) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2296) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2296) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2296) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2296) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2296)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)
# (pid=2296) 2024-12-12 12:59:43.745820: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# (pid=2296) 2024-12-12 12:59:43.780808: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# (pid=2296) 2024-12-12 12:59:43.791479: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# (pid=2296) 2024-12-12 12:59:45.979472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Generating train split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Generating train split:  17%|█▋        | 8400/50000 [00:00<00:00, 83246.08 examples/s]
# Generating train split:  35%|███▍      | 17300/50000 [00:00<00:00, 86271.65 examples/s]
# Generating train split:  53%|█████▎    | 26500/50000 [00:00<00:00, 88463.62 examples/s]
# Generating train split:  78%|███████▊  | 39100/50000 [00:00<00:00, 85798.17 examples/s]
# Generating train split: 100%|██████████| 50000/50000 [00:00<00:00, 87556.15 examples/s]
# Generating test split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Generating test split: 100%|██████████| 10000/10000 [00:00<00:00, 94458.43 examples/s]
# INFO :      Received initial parameters from one random client
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :
# [ROUND 1]
# INFO :      Round 1: Initial selection - Selected clients ['7278623158436271793', '11633785799934755291']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2295) /usr/local/lib/python3.10/dist-packages/jupyter_client/connect.py:28: DeprecationWarning: Jupyter is migrating its paths to use standard platformdirs
# (ClientAppActor pid=2295) given by the platformdirs library.  To remove this warning and
# (ClientAppActor pid=2295) see the appropriate new directories, set the environment variable
# (ClientAppActor pid=2295) `JUPYTER_PLATFORM_DIRS=1` and then run `jupyter --paths`.
# (ClientAppActor pid=2295) The use of platformdirs will be the default in `jupyter_core` v6
# (ClientAppActor pid=2295)   from jupyter_core.paths import jupyter_data_dir, jupyter_runtime_dir, secure_write
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2295)
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2295)             entirely in future versions of Flower.
# (ClientAppActor pid=2295)
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2295)
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2295)             entirely in future versions of Flower.
# (ClientAppActor pid=2295)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2296)          [repeated 4x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 7278623158436271793: accuracy = 0.2900 (prev: 0.0000)
# INFO :      Client 993647690490951350: accuracy = 0.2920 (prev: 0.0000)
# INFO :      Client 6952310741868811907: accuracy = 0.2890 (prev: 0.0000)
# INFO :      Client 1439591089059446246: accuracy = 0.2680 (prev: 0.0000)
# INFO :      Client 8169722648622496063: accuracy = 0.3010 (prev: 0.0000)
# INFO :      Client 11633785799934755291: accuracy = 0.2670 (prev: 0.0000)
# INFO :      Client 16706158009042529649: accuracy = 0.2630 (prev: 0.0000)
# INFO :      Client 10589111722045563843: accuracy = 0.2450 (prev: 0.0000)
# INFO :      Client 304078284742833344: accuracy = 0.2560 (prev: 0.0000)
# INFO :      Client 7481575764826779404: accuracy = 0.2780 (prev: 0.0000)
# INFO :      Round 1 aggregated accuracy: 0.2749
#
# INFO :
# INFO :      [ROUND 2]
# INFO :
# [ROUND 2]
# INFO :      Round 2: Initial selection - Selected clients ['10589111722045563843', '304078284742833344']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2295)          [repeated 8x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2295)          [repeated 10x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 6952310741868811907: accuracy = 0.3200 (prev: 0.2890)
# INFO :      Client 7481575764826779404: accuracy = 0.3280 (prev: 0.2780)
# INFO :      Client 304078284742833344: accuracy = 0.3250 (prev: 0.2560)
# INFO :      Client 8169722648622496063: accuracy = 0.3490 (prev: 0.3010)
# INFO :      Client 10589111722045563843: accuracy = 0.3040 (prev: 0.2450)
# INFO :      Client 16706158009042529649: accuracy = 0.2970 (prev: 0.2630)
# INFO :      Client 1439591089059446246: accuracy = 0.3250 (prev: 0.2680)
# INFO :      Client 993647690490951350: accuracy = 0.3450 (prev: 0.2920)
# INFO :      Client 11633785799934755291: accuracy = 0.3240 (prev: 0.2670)
# INFO :      Client 7278623158436271793: accuracy = 0.3460 (prev: 0.2900)
# INFO :      Round 2 aggregated accuracy: 0.3263
#
# INFO :
# INFO :      [ROUND 3]
# INFO :
# [ROUND 3]
# INFO :      Round 3: Initial selection - Selected clients ['16706158009042529649', '6952310741868811907']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2296)          [repeated 4x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2296)          [repeated 4x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 6952310741868811907: accuracy = 0.3490 (prev: 0.3200)
# INFO :      Client 11633785799934755291: accuracy = 0.3410 (prev: 0.3240)
# INFO :      Client 10589111722045563843: accuracy = 0.3550 (prev: 0.3040)
# INFO :      Client 1439591089059446246: accuracy = 0.3580 (prev: 0.3250)
# INFO :      Client 8169722648622496063: accuracy = 0.3940 (prev: 0.3490)
# INFO :      Client 16706158009042529649: accuracy = 0.3580 (prev: 0.2970)
# INFO :      Client 993647690490951350: accuracy = 0.3820 (prev: 0.3450)
# INFO :      Client 7481575764826779404: accuracy = 0.3840 (prev: 0.3280)
# INFO :      Client 304078284742833344: accuracy = 0.3640 (prev: 0.3250)
# INFO :      Client 7278623158436271793: accuracy = 0.3980 (prev: 0.3460)
# INFO :      Round 3 aggregated accuracy: 0.3683
#
# INFO :
# INFO :      [ROUND 4]
# INFO :
# [ROUND 4]
# INFO :      Round 4: Initial selection - Selected clients ['1439591089059446246', '993647690490951350']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2296)          [repeated 6x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2295)          [repeated 8x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 10589111722045563843: accuracy = 0.3950 (prev: 0.3550)
# INFO :      Client 16706158009042529649: accuracy = 0.3720 (prev: 0.3580)
# INFO :      Client 6952310741868811907: accuracy = 0.3930 (prev: 0.3490)
# INFO :      Client 7481575764826779404: accuracy = 0.4100 (prev: 0.3840)
# INFO :      Client 993647690490951350: accuracy = 0.4000 (prev: 0.3820)
# INFO :      Client 304078284742833344: accuracy = 0.3950 (prev: 0.3640)
# INFO :      Client 11633785799934755291: accuracy = 0.3970 (prev: 0.3410)
# INFO :      Client 8169722648622496063: accuracy = 0.4290 (prev: 0.3940)
# INFO :      Client 7278623158436271793: accuracy = 0.4200 (prev: 0.3980)
# INFO :      Client 1439591089059446246: accuracy = 0.3920 (prev: 0.3580)
# INFO :      Round 4 aggregated accuracy: 0.4003
#
# INFO :
# INFO :      [ROUND 5]
# INFO :
# [ROUND 5]
# INFO :      Round 5: Initial selection - Selected clients ['7481575764826779404', '8169722648622496063']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2295)          [repeated 4x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2295)          [repeated 8x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 1439591089059446246: accuracy = 0.4210 (prev: 0.3920)
# INFO :      Client 11633785799934755291: accuracy = 0.4200 (prev: 0.3970)
# INFO :      Client 7481575764826779404: accuracy = 0.4120 (prev: 0.4100)
# INFO :      Client 16706158009042529649: accuracy = 0.4140 (prev: 0.3720)
# INFO :      Client 6952310741868811907: accuracy = 0.4010 (prev: 0.3930)
# INFO :      Client 10589111722045563843: accuracy = 0.4280 (prev: 0.3950)
# INFO :      Client 7278623158436271793: accuracy = 0.4590 (prev: 0.4200)
# INFO :      Client 993647690490951350: accuracy = 0.4390 (prev: 0.4000)
# INFO :      Client 304078284742833344: accuracy = 0.4070 (prev: 0.3950)
# INFO :      Client 8169722648622496063: accuracy = 0.4540 (prev: 0.4290)
# INFO :      Round 5 aggregated accuracy: 0.4255
#
# INFO :
# INFO :      [ROUND 6]
# INFO :
# [ROUND 6]
# INFO :      Round 6: Probabilistic selection - Selected clients ['6952310741868811907', '304078284742833344']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2295)          [repeated 2x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2295)             entirely in future versions of Flower.
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 7278623158436271793: accuracy = 0.4450 (prev: 0.4590)
# INFO :      Client 11633785799934755291: accuracy = 0.4440 (prev: 0.4200)
# INFO :      Client 1439591089059446246: accuracy = 0.4390 (prev: 0.4210)
# INFO :      Client 7481575764826779404: accuracy = 0.4600 (prev: 0.4120)
# INFO :      Client 8169722648622496063: accuracy = 0.4740 (prev: 0.4540)
# INFO :      Client 16706158009042529649: accuracy = 0.4220 (prev: 0.4140)
# INFO :      Client 6952310741868811907: accuracy = 0.4320 (prev: 0.4010)
# INFO :      Client 993647690490951350: accuracy = 0.4850 (prev: 0.4390)
# INFO :      Client 304078284742833344: accuracy = 0.4340 (prev: 0.4070)
# INFO :      Client 10589111722045563843: accuracy = 0.4300 (prev: 0.4280)
# INFO :      Round 6 aggregated accuracy: 0.4465
#
# INFO :
# INFO :      [ROUND 7]
# INFO :
# [ROUND 7]
# INFO :      Round 7: Probabilistic selection - Selected clients ['993647690490951350', '16706158009042529649']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295)          [repeated 10x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 8x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 1439591089059446246: accuracy = 0.4530 (prev: 0.4390)
# INFO :      Client 304078284742833344: accuracy = 0.4440 (prev: 0.4340)
# INFO :      Client 10589111722045563843: accuracy = 0.4640 (prev: 0.4300)
# INFO :      Client 7481575764826779404: accuracy = 0.4530 (prev: 0.4600)
# INFO :      Client 11633785799934755291: accuracy = 0.4600 (prev: 0.4440)
# INFO :      Client 16706158009042529649: accuracy = 0.4390 (prev: 0.4220)
# INFO :      Client 993647690490951350: accuracy = 0.4920 (prev: 0.4850)
# INFO :      Client 6952310741868811907: accuracy = 0.4350 (prev: 0.4320)
# INFO :      Client 8169722648622496063: accuracy = 0.4850 (prev: 0.4740)
# INFO :      Client 7278623158436271793: accuracy = 0.4780 (prev: 0.4450)
# INFO :      Round 7 aggregated accuracy: 0.4603
#
# INFO :
# INFO :      [ROUND 8]
# INFO :
# [ROUND 8]
# INFO :      Round 8: Probabilistic selection - Selected clients ['11633785799934755291', '7278623158436271793']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2295)          [repeated 8x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295)          [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2295)             entirely in future versions of Flower.
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2295)          [repeated 6x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=2295)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=2296) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 7278623158436271793: accuracy = 0.5000 (prev: 0.4780)
# INFO :      Client 6952310741868811907: accuracy = 0.4430 (prev: 0.4350)
# INFO :      Client 16706158009042529649: accuracy = 0.4690 (prev: 0.4390)
# INFO :      Client 993647690490951350: accuracy = 0.5040 (prev: 0.4920)
# INFO :      Client 8169722648622496063: accuracy = 0.5070 (prev: 0.4850)
# INFO :      Client 11633785799934755291: accuracy = 0.4580 (prev: 0.4600)
# INFO :      Client 1439591089059446246: accuracy = 0.4620 (prev: 0.4530)
# INFO :      Client 7481575764826779404: accuracy = 0.4750 (prev: 0.4530)
# INFO :      Client 10589111722045563843: accuracy = 0.4730 (prev: 0.4640)
# INFO :      Client 304078284742833344: accuracy = 0.4550 (prev: 0.4440)
# INFO :      Round 8 aggregated accuracy: 0.4746
#
# INFO :
# INFO :      [ROUND 9]
# INFO :
# [ROUND 9]
# INFO :      Round 9: Probabilistic selection - Selected clients ['7481575764826779404', '10589111722045563843']
# INFO :      configure_fit: strategy sampled 2 clients (out of 10)
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=2296)             entirely in future versions of Flower. [repeated 4x across cluster]
# INFO :      aggregate_fit: received 2 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=2295)          [repeated 2x across cluster]
# (ClientAppActor pid=2295) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2295)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2295)             entirely in future versions of Flower.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2296) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=2296)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=2296)             entirely in future versions of Flower.
# (ClientAppActor pid=2295) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=2296)          [repeated 8x across cluster]
# ...
# (ClientAppActor pid=86430)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=86430)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=86430)          [repeated 8x across cluster]
# (ClientAppActor pid=86433) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=86433)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=86433)          [repeated 8x across cluster]
# (ClientAppActor pid=86433) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 6653004563849264978: accuracy = 0.5700 (prev: 0.5620)
# INFO :      Client 4525704482907238384: accuracy = 0.5650 (prev: 0.5530)
# INFO :      Client 5479644252211227987: accuracy = 0.5710 (prev: 0.5760)
# INFO :      Client 10228567603637565814: accuracy = 0.5860 (prev: 0.5880)
# INFO :      Client 1041414308055338219: accuracy = 0.5520 (prev: 0.5390)
# INFO :      Client 5700672175062921430: accuracy = 0.5700 (prev: 0.5700)
# INFO :      Client 16365942547475236218: accuracy = 0.5440 (prev: 0.5440)
# INFO :      Client 13856008004404803965: accuracy = 0.5680 (prev: 0.5570)
# INFO :      Client 1841880737604127566: accuracy = 0.5600 (prev: 0.5650)
# INFO :      Client 14141366016191161420: accuracy = 0.5490 (prev: 0.5570)
# INFO :      Round 19 aggregated accuracy: 0.5635
#
# INFO :
# INFO :      [ROUND 20]
# INFO :
# [ROUND 20]
# INFO :      Round 20: Probabilistic selection - Selected clients ['16365942547475236218', '4525704482907238384', '14141366016191161420', '5479644252211227987', '13856008004404803965', '6653004563849264978', '10228567603637565814']
# INFO :      configure_fit: strategy sampled 7 clients (out of 10)
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=86433)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=86433)          [repeated 8x across cluster]
# (ClientAppActor pid=86430) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 3x across cluster]
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=86433)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=86433)          [repeated 4x across cluster]
# (ClientAppActor pid=86430) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 2x across cluster]
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed [repeated 2x across cluster]
# (ClientAppActor pid=86433)             entirely in future versions of Flower. [repeated 2x across cluster]
# (ClientAppActor pid=86433)          [repeated 4x across cluster]
# (ClientAppActor pid=86430) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 2x across cluster]
# INFO :      aggregate_fit: received 7 results and 0 failures
# INFO :      configure_evaluate: strategy sampled 10 clients (out of 10)
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=86433)             entirely in future versions of Flower.
# (ClientAppActor pid=86433)          [repeated 2x across cluster]
# (ClientAppActor pid=86433) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=86430) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=86430)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=86430)             entirely in future versions of Flower.
# (ClientAppActor pid=86433) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`.
# (ClientAppActor pid=86433)          [repeated 8x across cluster]
# (ClientAppActor pid=86433) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 3x across cluster]
# (ClientAppActor pid=86433)             This is a deprecated feature. It will be removed [repeated 3x across cluster]
# (ClientAppActor pid=86433)             entirely in future versions of Flower. [repeated 3x across cluster]
# (ClientAppActor pid=86433) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# (ClientAppActor pid=86430)          [repeated 8x across cluster]
# (ClientAppActor pid=86430) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 4x across cluster]
# (ClientAppActor pid=86430)             This is a deprecated feature. It will be removed [repeated 4x across cluster]
# (ClientAppActor pid=86430)             entirely in future versions of Flower. [repeated 4x across cluster]
# (ClientAppActor pid=86430) WARNING :   Deprecation Warning: The `client_fn` function must return an instance of `Client`, but an instance of `NumpyClient` was returned. Please use `NumPyClient.to_client()` method to convert it to `Client`. [repeated 4x across cluster]
# INFO :      aggregate_evaluate: received 10 results and 0 failures
# INFO :      Client 13856008004404803965: accuracy = 0.5680 (prev: 0.5680)
# INFO :      Client 16365942547475236218: accuracy = 0.5400 (prev: 0.5440)
# INFO :      Client 1041414308055338219: accuracy = 0.5640 (prev: 0.5520)
# INFO :      Client 1841880737604127566: accuracy = 0.5570 (prev: 0.5600)
# INFO :      Client 5479644252211227987: accuracy = 0.5810 (prev: 0.5710)
# INFO :      Client 14141366016191161420: accuracy = 0.5740 (prev: 0.5490)
# INFO :      Client 6653004563849264978: accuracy = 0.5680 (prev: 0.5700)
# INFO :      Client 10228567603637565814: accuracy = 0.5880 (prev: 0.5860)
# INFO :      Client 4525704482907238384: accuracy = 0.5660 (prev: 0.5650)
# INFO :      Client 5700672175062921430: accuracy = 0.5840 (prev: 0.5700)
# INFO :      Round 20 aggregated accuracy: 0.5690
#
# INFO :      [SUMMARY]
# Total communication rounds: 140
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 20 round(s) in 867.98s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.06757136735916137
# INFO :      		round 2: 0.05619744458198547
# INFO :      		round 3: 0.05235950165987015
# INFO :      		round 4: 0.049934326499700546
# INFO :      		round 5: 0.04873176516890526
# INFO :      		round 6: 0.04704847497940064
# INFO :      		round 7: 0.045889858520030975
# INFO :      		round 8: 0.04482721446752548
# INFO :      		round 9: 0.04421274812221527
# INFO :      		round 10: 0.04394258128404617
# INFO :      		round 11: 0.042808765214681625
# INFO :      		round 12: 0.04218640895485878
# INFO :      		round 13: 0.04186859907507896
# INFO :      		round 14: 0.04116041417121887
# INFO :      		round 15: 0.04076180258989334
# INFO :      		round 16: 0.04061381492614746
# INFO :      		round 17: 0.040044436901807784
# INFO :      		round 18: 0.039640632498264314
# INFO :      		round 19: 0.039181806033849714
# INFO :      		round 20: 0.038997419875860216
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.263),
# INFO :      	              (2, 0.3603),
# INFO :      	              (3, 0.4035),
# INFO :      	              (4, 0.4306),
# INFO :      	              (5, 0.4475),
# INFO :      	              (6, 0.471),
# INFO :      	              (7, 0.4885),
# INFO :      	              (8, 0.4989),
# INFO :      	              (9, 0.5047),
# INFO :      	              (10, 0.5049),
# INFO :      	              (11, 0.5257),
# INFO :      	              (12, 0.5301),
# INFO :      	              (13, 0.5348),
# INFO :      	              (14, 0.541),
# INFO :      	              (15, 0.5466),
# INFO :      	              (16, 0.5442),
# INFO :      	              (17, 0.5601),
# INFO :      	              (18, 0.5611),
# INFO :      	              (19, 0.5635),
# INFO :      	              (20, 0.569)]}
# INFO :
# Completed simulation with k=7, alpha=0.8: Accuracy=0.569, Communications=140
#
# All experiments completed. Results saved to experiment_results.csv
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bbce4809-6bdf-42d4-b072-253b21a56fa9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bbce4809-6bdf-42d4-b072-253b21a56fa9")) {                    Plotly.newPlot(                        "bbce4809-6bdf-42d4-b072-253b21a56fa9",                        [{"customdata":[[2.0,0.1]],"hovertemplate":"Parameters=k=2.0, alpha=0.1\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=2.0, alpha=0.1","marker":{"color":"#636efa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=2.0, alpha=0.1","orientation":"v","showlegend":true,"x":[0.5369],"xaxis":"x","y":[40],"yaxis":"y","type":"scatter"},{"customdata":[[2.0,0.2]],"hovertemplate":"Parameters=k=2.0, alpha=0.2\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=2.0, alpha=0.2","marker":{"color":"#EF553B","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=2.0, alpha=0.2","orientation":"v","showlegend":true,"x":[0.538],"xaxis":"x","y":[40],"yaxis":"y","type":"scatter"},{"customdata":[[2.0,0.5]],"hovertemplate":"Parameters=k=2.0, alpha=0.5\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=2.0, alpha=0.5","marker":{"color":"#00cc96","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=2.0, alpha=0.5","orientation":"v","showlegend":true,"x":[0.5421],"xaxis":"x","y":[40],"yaxis":"y","type":"scatter"},{"customdata":[[2.0,0.8]],"hovertemplate":"Parameters=k=2.0, alpha=0.8\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=2.0, alpha=0.8","marker":{"color":"#ab63fa","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=2.0, alpha=0.8","orientation":"v","showlegend":true,"x":[0.5413],"xaxis":"x","y":[40],"yaxis":"y","type":"scatter"},{"customdata":[[3.0,0.1]],"hovertemplate":"Parameters=k=3.0, alpha=0.1\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=3.0, alpha=0.1","marker":{"color":"#FFA15A","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=3.0, alpha=0.1","orientation":"v","showlegend":true,"x":[0.5572],"xaxis":"x","y":[60],"yaxis":"y","type":"scatter"},{"customdata":[[3.0,0.2]],"hovertemplate":"Parameters=k=3.0, alpha=0.2\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTotal Communication Rounds=%{y}\u003cbr\u003ek=%{customdata[0]}\u003cbr\u003ealpha=%{customdata[1]}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"k=3.0, alpha=0.2","marker":{"color":"#19d3f3","symbol":"circle","line":{"color":"DarkSlateGrey","width":1},"opacity":0.8,"size":12},"mode":"markers","name":"k=3.0, alpha=0.2","orientation":"v","showlegend":true,"x":[0.5575],"xaxis":"x","y":[60],"yaxis":"y","type":"scatter"},{"customdata":[[3.0,0.5]],"hovertemplate":"Parameters=k=3.0, alpha=0.5\u003cbr\u003eFinal Accuracy=%{x:.4f}\u003cbr\u003eTota ...
